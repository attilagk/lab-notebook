# %% [markdown]
# Looking for somatic calls in or near neurexins

# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
from matplotlib import pyplot as plt
import pandas as pd
import re
# %matplotlib inline

# %%
# %%bash
# NRXNcalls=/home/attila/projects/bsm/results/2020-09-30-neurexin/NRXN-calls.csv
# cd /home/attila/projects/bsm/results/2020-09-07-annotations
# sed 1q annotated-calls.csv > $NRXNcalls
# grep NRXN annotated-calls.csv >> $NRXNcalls

# %%
index_col = ['Individual ID', 'Tissue', 'CHROM', 'POS', 'Mutation']
fpath = '/home/attila/projects/bsm/results/2020-09-30-neurexin/NRXN-calls.csv'
#calls = pd.read_csv('/home/attila/projects/bsm/results/2020-09-07-annotations/annotated-calls.csv', index_col=index_col)
neurexin = pd.read_csv(fpath, index_col=index_col)
neurexin
# Out:
#                                               REF ALT    QUAL    FILTER/PASS  \
# Individual ID Tissue  CHROM POS      Mutation
# CMC_MSSM_056  NeuN_pl 14    79813335 T/C        T   C  256.58   HC;PASS/PASS
# CMC_MSSM_222  NeuN_pl 11    64439850 G/A        G   A  169.72   HC;PASS/PASS
# CMC_MSSM_321  NeuN_pl 14    78971952 G/A        G   A   67.36  EXT;PASS/PASS
# CMC_MSSM_340  NeuN_pl 2     50864732 A/G        A   G   60.43   HC;PASS/PASS
# CMC_MSSM_370  NeuN_pl 14    79720303 T/C        T   C   87.73   HC;PASS/PASS
#
#                                                  FILTER/HC    FILTER/EXT  AC  \
# Individual ID Tissue  CHROM POS      Mutation
# CMC_MSSM_056  NeuN_pl 14    79813335 T/C        HC;PASS/HC   HC;PASS/EXT   6
# CMC_MSSM_222  NeuN_pl 11    64439850 G/A        HC;PASS/HC   HC;PASS/EXT   2
# CMC_MSSM_321  NeuN_pl 14    78971952 G/A       EXT;PASS/HC  EXT;PASS/EXT   1
# CMC_MSSM_340  NeuN_pl 2     50864732 A/G        HC;PASS/HC   HC;PASS/EXT   1
# ...

# %%
near_gens_cols = [y for y in  neurexin.columns if re.match('.*near_gens.*', y)]
neurexin[['Dx'] + near_gens_cols]
# Out:
#                                                     Dx  \
# Individual ID Tissue  CHROM POS      Mutation
# CMC_MSSM_056  NeuN_pl 14    79813335 T/C       Control
# CMC_MSSM_222  NeuN_pl 11    64439850 G/A           SCZ
# CMC_MSSM_321  NeuN_pl 14    78971952 G/A           SCZ
# CMC_MSSM_340  NeuN_pl 2     50864732 A/G           SCZ
# CMC_MSSM_370  NeuN_pl 14    79720303 T/C           SCZ
#
#                                               near_gens_Overlapped Gene  \
# Individual ID Tissue  CHROM POS      Mutation
# CMC_MSSM_056  NeuN_pl 14    79813335 T/C                          NRXN3
# CMC_MSSM_222  NeuN_pl 11    64439850 G/A                          NRXN2
# CMC_MSSM_321  NeuN_pl 14    78971952 G/A                          NRXN3
# CMC_MSSM_340  NeuN_pl 2     50864732 A/G                          NRXN1
# CMC_MSSM_370  NeuN_pl 14    79720303 T/C                          NRXN3
#
#                                                near_gens_Type  \
# ...

# %%
# %connect_info
# Out:
# {
#   "shell_port": 49365,
#   "iopub_port": 35083,
#   "stdin_port": 39335,
#   "control_port": 60501,
#   "hb_port": 47759,
#   "ip": "127.0.0.1",
#   "key": "5ca0dd25-5043d6e6485ee0771e7ae83f",
#   "transport": "tcp",
#   "signature_scheme": "hmac-sha256",
#   "kernel_name": ""
# }
#
# Paste the above JSON into a file, and connect with:
#     $> jupyter <app> --existing <file>
# or, if you are local, you can connect with just:
#     $> jupyter <app> --existing kernel-d59134a3-f656-4983-a041-8633f4ad782d.json
# or even just:
#     $> jupyter <app> --existing
# if this is the most recent Jupyter kernel you have started.

# %%
# %connect_info
# Out:
# {
#   "shell_port": 49365,
#   "iopub_port": 35083,
#   "stdin_port": 39335,
#   "control_port": 60501,
#   "hb_port": 47759,
#   "ip": "127.0.0.1",
#   "key": "5ca0dd25-5043d6e6485ee0771e7ae83f",
#   "transport": "tcp",
#   "signature_scheme": "hmac-sha256",
#   "kernel_name": ""
# }
#
# Paste the above JSON into a file, and connect with:
#     $> jupyter <app> --existing <file>
# or, if you are local, you can connect with just:
#     $> jupyter <app> --existing kernel-d59134a3-f656-4983-a041-8633f4ad782d.json
# or even just:
#     $> jupyter <app> --existing
# if this is the most recent Jupyter kernel you have started.
