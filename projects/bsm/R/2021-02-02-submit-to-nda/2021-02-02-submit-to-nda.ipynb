# %% [markdown]
# Submitting data from Synapse scratch space

# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
import synapseclient
import cmc_submit2ndar as s2n
import pandas as pd
import numpy as np
import pickle
import os.path
import re

# %%
syn = synapseclient.login()
# Out:
# Welcome, Attila Jones!

# %% [markdown]
# ## Data files to submit
# These data files have different types marked by their extension

# %%
fpath = '/home/attila/projects/bsm/results/2021-02-02-submit-to-nda/files_not_uploaded_yet.MSSM.txt'
picklepath = fpath + '.p'
if not os.path.exists(picklepath):
    dfiles = s2n.read_dfiles(syn, fpath)
    pickle.dump(dfiles, open(picklepath, 'wb'))
else:
    print('loading file from', picklepath)
    with open(picklepath, 'rb') as f:
        dfiles = pickle.load(f)
dfiles
# Out:
# loading file from /home/attila/projects/bsm/results/2021-02-02-submit-to-nda/files_not_uploaded_yet.MSSM.txt.p
#                              synapseID                       filename  \
# indivID      filetype
# CMC_MSSM_027 cram          syn22007834          MSSM_027_NeuN_pl.cram
# CMC_MSSM_033 cram          syn22090557          MSSM_033_NeuN_pl.cram
# CMC_MSSM_055 cram          syn22162964          MSSM_055_NeuN_pl.cram
# CMC_MSSM_056 cram          syn22093909          MSSM_056_NeuN_pl.cram
# CMC_MSSM_063 cram          syn22150192          MSSM_063_NeuN_pl.cram
# ...                                ...                            ...
# CMC_PITT_072 unmapped.bam  syn22385266  PITT_072_NeuN_pl.unmapped.bam
# CMC_PITT_082 unmapped.bam  syn22384272  PITT_082_NeuN_pl.unmapped.bam
# CMC_PITT_098 unmapped.bam  syn22385231  PITT_098_NeuN_pl.unmapped.bam
# CMC_PITT_101 unmapped.bam  syn22381683  PITT_101_NeuN_pl.unmapped.bam
# CMC_PITT_113 unmapped.bam  syn22385324  PITT_113_NeuN_pl.unmapped.bam
#
#                                                                   data_file1
# indivID      filetype
# CMC_MSSM_027 cram          5229ec83-c2eb-4f44-8d2b-f688b476bbda/MSSM_027_...
# CMC_MSSM_033 cram          475392a7-5f20-4a07-8694-9dc86a677032/MSSM_033_...
# CMC_MSSM_055 cram          e55eb946-1335-4dd5-a26b-85d74b5e3a36/MSSM_055_...
# CMC_MSSM_056 cram          af069550-3c69-4e3a-bbb3-48d532d2c21c/MSSM_056_...
# CMC_MSSM_063 cram          d98961ae-eef8-4eb3-8be8-5a79f9fda507/MSSM_063_...
# ...                                                                      ...
# CMC_PITT_072 unmapped.bam  bc52db52-ba9d-49e4-a9fb-5bc2ec7e22e3/PITT_072_...
# CMC_PITT_082 unmapped.bam  a877be33-4ca7-4165-b2a3-178bbd818d0f/PITT_082_...
# CMC_PITT_098 unmapped.bam  abbcfd1c-e2f8-4cdd-8bb3-8b26c0a26788/PITT_098_...
# CMC_PITT_101 unmapped.bam  2b8d3b25-3654-43e8-b188-a4089b1afd93/PITT_101_...
# CMC_PITT_113 unmapped.bam  8dc9dc6f-61df-4d90-a36b-f4a32bdff594/PITT_113_...
#
# [809 rows x 3 columns]

# %% [markdown]
# The `prefixes` dictionary contains the AWS S3 prefix for each file type

# %%
prefixes = {'cram': '3338602',
            'cram.crai': '3338602',
            'flagstat.txt': '3340241',
            'ploidy_2.vcf.gz': '3340241',
            'ploidy_2.vcf.gz.tbi': '3340241',
            'ploidy_12.vcf.gz': '3340241',
            'ploidy_12.vcf.gz.tbi': '3340241',
            'ploidy_50.vcf.gz': '3340241',
            'ploidy_50.vcf.gz.tbi': '3340241',
            'unmapped.bam': '3338602'
           }
ftypes = dfiles.index.get_level_values(1).unique()
set(ftypes) == set(prefixes.keys())
# Out:
# True

# %% [markdown]
# ## Creating `genomics_subject02` and `nichd_btb02`
# These refer to the same samples and subjects as the ones submitted with the FASTQ files.  Since there were two FASTQ submissions for these set of samples I merge them

# %%
def foo(maniftype='genomics_subject02'):
    basen = '/home/attila/projects/bsm/results/2021-02-02-submit-to-nda/' + maniftype + '-'
    fpaths = [basen + x + '.csv' for x in ['2019-12-09', '2020-06-08']]
    manif = pd.concat([pd.read_csv(x, skiprows=1) for x in fpaths], axis=0)
    target_path = '/home/attila/projects/bsm/results/2021-02-02-submit-to-nda/' + maniftype +'-2021-02-02.csv'
    template_path = '/home/attila/projects/bsm/results/2020-04-22-upload-to-ndar-from-s3/chess-' + maniftype + '.csv'
    s2n.write_manifest(manif, template_path=template_path, target_path=target_path)
    return(manif)

gsub = foo('genomics_subject02')
btb = foo('nichd_btb02')

# %% [markdown]
# ## Creating `genomics_sample03`
#
# ### `genomics_sample03` filled template
#
# I take `genomics_sample03` from a previous submission that was used for the FASTQ files for the same set of 81 samples.  I name this manifest `oldgsam`

# %%
basen = '/home/attila/projects/bsm/results/2021-02-02-submit-to-nda/genomics_sample03-'
fpaths = [basen + x + '.csv' for x in ['2019-12-09', '2020-06-08']]
oldgsam = pd.concat([pd.read_csv(x, skiprows=1) for x in fpaths], axis=0)
oldgsam
# Out:
#           subjectkey  experiment_id src_subject_id  interview_age  \
# 0   NDAR_INV0971H4H4           1223   CMC_MSSM_033            972
# 1   NDAR_INV0971H4H4           1223   CMC_MSSM_033            972
# 2   NDAR_INV1VPUF5CL           1223   CMC_MSSM_056            804
# 3   NDAR_INV1VPUF5CL           1223   CMC_MSSM_056            804
# 4   NDAR_INV1VPUF5CL           1223   CMC_MSSM_056            804
# ..               ...            ...            ...            ...
# 64  NDAR_INVTY432EB9           1223   CMC_MSSM_379            852
# 65  NDAR_INVLH141LX6           1223   CMC_MSSM_340            912
# 66  NDAR_INVAK206LGH           1223   CMC_MSSM_362            876
# 67  NDAR_INVTM018EUJ           1223   CMC_MSSM_405            708
# 68  NDAR_INVDZ834FVN           1223   CMC_PITT_052            708
#
#    interview_date sample_description       sample_id_original organism  \
# 0      04/13/2018     frontal cortex  MSSM_033.DLPFC_1355.np1    human
# 1      04/13/2018     frontal cortex  MSSM_033.DLPFC_1355.np1    human
# 2      04/13/2018     frontal cortex  MSSM_056.DLPFC_1181.np1    human
# 3      04/13/2018     frontal cortex  MSSM_056.DLPFC_1181.np1    human
# 4      04/13/2018     frontal cortex  MSSM_056.DLPFC_1181.np1    human
# ..            ...                ...                      ...      ...
# 64     06/08/2020     frontal cortex                 1238.np1    human
# 65     06/08/2020     frontal cortex                 1247.np1    human
# 66     06/08/2020     frontal cortex                 1346.np1    human
# 67     06/08/2020     frontal cortex                 1357.np1    human
# 68     06/08/2020     frontal cortex                 1454.np1    human
#
#     sample_amount sample_unit  ...  patient_id_biorepository  \
# 0             1.0         NaN  ...              CMC_MSSM_033
# 1             1.0         NaN  ...              CMC_MSSM_033
# 2          1543.0          ng  ...              CMC_MSSM_056
# 3          1543.0          ng  ...              CMC_MSSM_056
# 4          1543.0          ng  ...              CMC_MSSM_056
# ..            ...         ...  ...                       ...
# 64            1.0         NaN  ...              CMC_MSSM_379
# 65            1.0         NaN  ...              CMC_MSSM_340
# 66            1.0         NaN  ...              CMC_MSSM_362
# 67            1.0         NaN  ...              CMC_MSSM_405
# 68            1.0         NaN  ...              CMC_PITT_052
#
#     sample_id_biorepository cell_id_original cell_id_biorepository  \
# 0   MSSM_033.DLPFC_1355.np1              NaN                   NaN
# 1   MSSM_033.DLPFC_1355.np1              NaN                   NaN
# 2   MSSM_056.DLPFC_1181.np1              NaN                   NaN
# 3   MSSM_056.DLPFC_1181.np1              NaN                   NaN
# 4   MSSM_056.DLPFC_1181.np1              NaN                   NaN
# ..                      ...              ...                   ...
# 64                 1238.np1              NaN                   NaN
# 65                 1247.np1              NaN                   NaN
# 66                 1346.np1              NaN                   NaN
# 67                 1357.np1              NaN                   NaN
# 68                 1454.np1              NaN                   NaN
#
#    comments_misc         site  rat280  rat230  gqn  seq_batch
# 0            NaN  U01MH106891     NaN     NaN  NaN        NaN
# 1            NaN  U01MH106891     NaN     NaN  NaN        NaN
# 2            NaN  U01MH106891     NaN     NaN  NaN        NaN
# 3            NaN  U01MH106891     NaN     NaN  NaN        NaN
# 4            NaN  U01MH106891     NaN     NaN  NaN        NaN
# ..           ...          ...     ...     ...  ...        ...
# 64           NaN  U01MH106891     NaN     NaN  NaN        NaN
# 65           NaN  U01MH106891     NaN     NaN  NaN        NaN
# 66           NaN  U01MH106891     NaN     NaN  NaN        NaN
# 67           NaN  U01MH106891     NaN     NaN  NaN        NaN
# 68           NaN  U01MH106891     NaN     NaN  NaN        NaN
#
# [186 rows x 32 columns]

# %% [markdown]
# ### Editing `genomics_sample03`
#
# The `edit_gsam` function takes the `oldgsam` template and simplifies it to one row for each sample.  Then it replaces the `data_file1_type` and `data_file1` fields with the file type (e.g `unmapped` and `295ba82f-8f14-4e50-8945-4496f5131c9e/MSSM_027_NeuN_pl.unmapped.bam`, respectively).
#
# `edit_gsam` edits `data_file1` in a certain way; see Cindy Molitor's email from Nov 30, 2020, 1:29 PM
#
# > Note that the s3 prefix for the scratch bucket should not be included in the file path in the data_file columns, e.g. the value of the column should be
# >
# > 89eac311-84e3-4be0-9f0e-c6186104f71c/NC1-CX-ASTMIG.cram
# >
# > instead of
# >
# > 3340241/89eac311-84e3-4be0-9f0e-c6186104f71c/NC1-CX-ASTMIG.cram

# %%
template_path = '/home/attila/projects/bsm/results/2020-04-22-upload-to-ndar-from-s3/genomics_sample03_template.csv'
def foo(ftype):
    gsam = s2n.edit_gsam(oldgsam, dfiles, gender=gsub.set_index('src_subject_id')['gender'], dftype=ftype)
    target_path = '/home/attila/projects/bsm/results/2021-02-02-submit-to-nda/genomics_sample03-' + ftype + '.csv'
    s2n.write_manifest(gsam, template_path=template_path, target_path=target_path)
    return(gsam)

gsamd = {ftype: foo(ftype) for ftype in ftypes}

# %% [markdown]
# ## Submission
# First submit everything except for `unmapped.bam`s because `PITT_117_NeuN_pl.unmapped.bam` is still missing

# %%
# %%bash
# cd ~/projects/bsm/results/2021-02-02-submit-to-nda
# validate="vtcmd -b -t title -d description -s3 nda-bsmn-scratch -pre 3338602 -u $NDA_USER -p $NDA_PASSWORD -ak ASIAZAAXFM2FOHMRXZUH -sk 'gimUKU1I3rActmMBYSiw9dLBEzQhOw7WCrRiq8+B' -c 2965 -w"
# manifests="nichd_btb02-2021-02-02.csv genomics_subject02-2021-02-02.csv"
# dftypes="cram.crai cram flagstat.txt ploidy_2.vcf.gz ploidy_2.vcf.gz.tbi ploidy_12.vcf.gz ploidy_12.vcf.gz.tbi ploidy_50.vcf.gz ploidy_50.vcf.gz.tbi unmapped.bam"
# for dftype in $dftypes; do
# echo $dftype
# $validate $manifests genomics_sample03-$dftype.csv
# echo '----'
# done
# Out:
# cram.crai
# Running NDATools Version 0.2.3
# Opening log: /home/attila/NDAValidationResults/debug_log_20210222T210149.txt
#
# Validating files...
# Validation report output to: /home/attila/NDAValidationResults/validation_results_20210222T210149.csv
# Warnings output to: /home/attila/NDAValidationResults/validation_results_20210222T210149.csv
#
# All files have finished validating.
#
# The following files passed validation:
# UUID c9b5bbbd-4bf2-4587-8a22-73a7de2fc8a8: genomics_subject02-2021-02-02.csv
# UUID cee61d03-7f7c-49a4-8df3-89ec94ae157e: genomics_sample03-cram.crai.csv
# UUID f691eb48-04a5-46a9-a7cd-274168e20c45: nichd_btb02-2021-02-02.csv
#
# Searching for associated files...
#
#  Your user does NOT have access to the following buckets. Please review the bucket and/or your AWS credentials and try again.
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
#
#  You must make sure all associated files listed in your validation file are located in the specified directory or AWS bucket. Associated file not found in specified directory:
#
# 05f79a82-9d7c-4353-81e6-673f00f081d9/MSSM_161_NeuN_pl.cram.crai
# 06d4fef1-e0cd-4af4-95e4-805a711e939e/MSSM_338_NeuN_pl.cram.crai
# 085e9b76-bf7c-4f64-b38f-784b3baeb36e/MSSM_193_NeuN_pl.cram.crai
# 089412d1-31e2-449e-badd-374c84dd7d7c/MSSM_065_NeuN_pl.cram.crai
# 0a1450ec-06ed-4cea-82fd-b6396dab9d44/MSSM_340_NeuN_pl.cram.crai
# 0ac4715e-3185-4e34-a8d9-e90d623f9f22/MSSM_309_NeuN_pl.cram.crai
# 0f5a8566-d9c2-4052-9350-f485457b212c/MSSM_352_NeuN_pl.cram.crai
# 11a90da4-e4ae-4512-a189-a36b42490041/MSSM_299_NeuN_pl.cram.crai
# 12babdfe-215d-4303-8e84-c5c8b9f170d8/PITT_072_NeuN_pl.cram.crai
# 1a931943-ff37-4e3d-bb87-4c2429b18b0b/MSSM_406_NeuN_pl.cram.crai
# 1e00bb45-0759-4888-b63e-98cce96f9a2b/PITT_052_NeuN_pl.cram.crai
# 1f143de1-e2f5-43f2-92b5-b65d02da32c2/MSSM_265_NeuN_pl.cram.crai
# 26d18111-93a6-4ac2-a0df-bc4b4be1fa09/PITT_020_NeuN_pl.cram.crai
# 2e86966c-e784-42e7-9ac3-879eb5562a54/MSSM_222_NeuN_pl.cram.crai
# 2ed3bbd2-6cf7-43a9-92e3-c485a7d65d71/MSSM_304_NeuN_pl.cram.crai
# 2f054e81-8a8c-4bed-883e-cf5157c39eba/MSSM_362_NeuN_pl.cram.crai
# 30e1f5b4-3f89-4633-ba6d-8af343e2700a/MSSM_168_NeuN_pl.cram.crai
# 32dbeff1-8892-43c8-bb68-12b8bd164e8a/MSSM_343_NeuN_pl.cram.crai
# 35dea27a-cdf5-422a-861f-e73da500f675/MSSM_405_NeuN_pl.cram.crai
# 3701c8bd-deee-4775-9685-b3a17bea6314/MSSM_178_NeuN_pl.cram.crai
# 3a718df8-522b-494e-b465-288fea3c7dc8/MSSM_224_NeuN_pl.cram.crai
# 3eee56f1-29ad-49b7-a5f5-c4e5dcf6f85b/MSSM_158_NeuN_pl.cram.crai
# 423eb849-c5f2-48ee-ac62-d8ac07bd9c9a/MSSM_069_NeuN_pl.cram.crai
# 46766bce-ec31-47ed-a57e-5d4e9a400e62/PITT_113_NeuN_pl.cram.crai
# 4a4aa82d-1e3f-4aa4-a7bf-7520d70fe9ad/MSSM_348_NeuN_pl.cram.crai
# 4b64507f-a6d4-4797-91ca-ade48a0548a5/MSSM_364_NeuN_pl.cram.crai
# 4c19d600-024e-4fff-b2aa-ecadf5e36f9b/MSSM_273_NeuN_pl.cram.crai
# 5155200f-cab8-447a-96f4-9ea5a0fcf004/MSSM_116_NeuN_pl.cram.crai
# 5382cffa-ad0f-407a-af87-bdc8d61288c1/MSSM_415_NeuN_pl.cram.crai
# 587e355d-d7e5-4de2-99b6-85992f1f9958/MSSM_199_NeuN_pl.cram.crai
# 58d3d16f-4355-43d5-a2b7-8cd34c070054/MSSM_100_NeuN_pl.cram.crai
# 5e4b8abb-8b3b-405c-badd-8dac4ded2622/PITT_060_NeuN_pl.cram.crai
# 5ed72012-5a2a-416b-8f27-f1011c131d45/MSSM_372_NeuN_pl.cram.crai
# 5ffa72bf-1c54-4531-b7e8-1fa3e7936613/MSSM_308_NeuN_pl.cram.crai
# 61f8180f-d01d-402f-bac2-eee983cc497e/MSSM_142_NeuN_pl.cram.crai
# 66c508a2-4710-475c-90c3-0814823f2b24/PITT_071_NeuN_pl.cram.crai
# 67257fd2-f63d-49ec-8d55-9ce21d2bb2a8/PITT_004_NeuN_pl.cram.crai
# 6938fa78-387f-4b0a-aaf7-89f036883496/MSSM_269_NeuN_pl.cram.crai
# 7d299a31-c08c-4b5a-a500-777ca8787414/MSSM_213_NeuN_pl.cram.crai
# 8108fe53-23e6-4468-80a7-1bc58b46e60f/MSSM_370_NeuN_pl.cram.crai
# 86dfd91f-dfd7-441f-995e-dcb2e78495a6/MSSM_327_NeuN_pl.cram.crai
# 89c0d108-0635-4f76-bcdc-411d6aee3fe8/MSSM_033_NeuN_pl.cram.crai
# 8f275ee1-944f-4aec-baf7-dfbed1485666/MSSM_227_NeuN_pl.cram.crai
# 8f27f226-02b5-4fd1-8f82-c0c3299f9e26/MSSM_297_NeuN_pl.cram.crai
# 8fa82b20-8744-42df-9e9b-e5e3d71f3ca6/MSSM_339_NeuN_pl.cram.crai
# 91f1242e-78e2-4929-ac30-9e0d4fb8a8b8/MSSM_192_NeuN_pl.cram.crai
# 9794d9a4-8316-4e9c-ac5e-13ad665c8aa5/MSSM_130_NeuN_pl.cram.crai
# 9f42c0e6-7e80-4f86-9cb5-540bd81cc37d/MSSM_055_NeuN_pl.cram.crai
# a148a7db-37f0-4dc7-a3db-187d97c54d3c/PITT_024_NeuN_pl.cram.crai
# a236b72e-3826-4419-aa73-4071cb9a148d/PITT_098_NeuN_pl.cram.crai
# a5e7a4ad-266a-4391-b59a-915f2c574daf/MSSM_164_NeuN_pl.cram.crai
# ab281ba7-5aa4-4e0e-a8f7-cb880a7e566c/MSSM_201_NeuN_pl.cram.crai
# afc79e87-456b-4b72-b194-1fdb598eda47/MSSM_287_NeuN_pl.cram.crai
# b1745aff-af56-4f8a-b94b-eb6e8801fc0e/MSSM_346_NeuN_pl.cram.crai
# b82a0d24-fe87-4d34-ad1e-45b73f5a9996/MSSM_310_NeuN_pl.cram.crai
# b9e597e9-19e5-42fc-b368-48ffe9a481ea/MSSM_254_NeuN_pl.cram.crai
# babf1519-b3c3-45c3-9bf7-0c824176dcf4/MSSM_305_NeuN_pl.cram.crai
# bbf8b03f-3bac-49dd-99ec-d6edcde95afb/MSSM_291_NeuN_pl.cram.crai
# bd4fd333-2220-4e79-8db2-66ef38fa82fe/MSSM_211_NeuN_pl.cram.crai
# c012abcb-5bde-4c9c-aee8-4ddbb8570696/PITT_036_NeuN_pl.cram.crai
# c86d3e68-ba52-4c70-a35f-bee43752b9ba/MSSM_366_NeuN_pl.cram.crai
# ca76bd08-1efb-40db-bcfb-5e3f3edf58b2/PITT_007_NeuN_pl.cram.crai
# cb31d525-9b4b-47db-9e8a-f109bd724d8e/MSSM_331_NeuN_pl.cram.crai
# cdd8765b-4320-4880-bae8-e8cc99ea1a96/MSSM_363_NeuN_pl.cram.crai
# d3327f37-7c9f-43b7-813d-02ea91c03209/MSSM_180_NeuN_pl.cram.crai
# d6094e19-0d9f-4543-afc7-148423d1dce3/MSSM_162_NeuN_pl.cram.crai
# d6e15f1e-95bc-4e53-82d9-f860788e7e99/MSSM_063_NeuN_pl.cram.crai
# d927476c-fdb1-4fda-8bc8-ded28cf9b1f2/PITT_017_NeuN_pl.cram.crai
# d99a98ee-6e12-433d-9539-5df672632d96/PITT_101_NeuN_pl.cram.crai
# da631c4b-f3ea-4514-a1c4-bce229938aa4/MSSM_099_NeuN_pl.cram.crai
# dbfe4efb-5b62-4189-9f06-b54d927961d1/PITT_117_NeuN_pl.cram.crai
# dd7b2bcf-d562-48bd-8f36-047cfed3486c/MSSM_056_NeuN_pl.cram.crai
# dd9d5f5c-87f9-4905-acf4-87a366edd37b/MSSM_293_NeuN_pl.cram.crai
# e1938a7e-0f97-4bbf-b824-190da387b51d/MSSM_321_NeuN_pl.cram.crai
# e3021a75-a08f-464c-b083-63125cb58cd4/PITT_050_NeuN_pl.cram.crai
# e7650221-36c8-4059-b6a7-8fdf32e3eb28/MSSM_379_NeuN_pl.cram.crai
# ed1bf912-b3c8-40ab-871b-6fa5d7152512/MSSM_027_NeuN_pl.cram.crai
# f73933fa-4122-4b96-b919-c8d230a1e033/MSSM_295_NeuN_pl.cram.crai
# f763c66b-6473-4636-a8ba-daa920fd6640/MSSM_097_NeuN_pl.cram.crai
# f9809ddf-f220-4721-89e8-74df7149f637/MSSM_266_NeuN_pl.cram.crai
# fb1b19f1-75dd-430d-a59c-fb366009a21a/PITT_082_NeuN_pl.cram.crai
# Press the "Enter" key to specify directory/directories OR an s3 location by entering -s3 <bucket name> to locate your associated files:----
# cram
# Running NDATools Version 0.2.3
# Opening log: /home/attila/NDAValidationResults/debug_log_20210222T210156.txt
#
# Validating files...
# Validation report output to: /home/attila/NDAValidationResults/validation_results_20210222T210156.csv
# Warnings output to: /home/attila/NDAValidationResults/validation_results_20210222T210156.csv
#
# All files have finished validating.
#
# The following files passed validation:
# UUID e248d6ba-48f9-4c59-ac55-24320c2bd003: genomics_subject02-2021-02-02.csv
# UUID b6a3d496-5854-487f-9a4d-e5e0ae638d6a: genomics_sample03-cram.csv
# UUID 2cbe3c20-2047-4d4f-ad72-20cff9a1ac0a: nichd_btb02-2021-02-02.csv
#
# Searching for associated files...
#
#  Your user does NOT have access to the following buckets. Please review the bucket and/or your AWS credentials and try again.
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
#
#  You must make sure all associated files listed in your validation file are located in the specified directory or AWS bucket. Associated file not found in specified directory:
#
# 0187fec3-4fef-49bd-a26b-21f30847c691/MSSM_348_NeuN_pl.cram
# 0bfe3555-c175-4b7f-9606-9a4d8d96cc52/MSSM_340_NeuN_pl.cram
# 0f3dc045-0c64-4c0e-bd1d-3d106d2e6337/MSSM_338_NeuN_pl.cram
# 11181b3c-013c-4156-8c71-7a285e0149d4/MSSM_199_NeuN_pl.cram
# 15296f0b-7b79-4f1d-8f05-dc7a40446a67/MSSM_266_NeuN_pl.cram
# 154cd720-75f6-426c-a601-4d3cc8a6b85b/PITT_024_NeuN_pl.cram
# 18d80be0-968e-4a41-ac45-4efb2730cd15/PITT_007_NeuN_pl.cram
# 19c45ea1-418b-4f06-afb6-1f11c7fac33b/MSSM_269_NeuN_pl.cram
# 1b955a00-0fa0-48d1-9d42-bef94228f0ae/PITT_071_NeuN_pl.cram
# 20db599a-1180-490d-88d3-5cbed6c31649/PITT_050_NeuN_pl.cram
# 2145a3f4-7adf-435e-b0ce-9daedaf27d25/MSSM_309_NeuN_pl.cram
# 225e60d6-acb4-4aad-89eb-8e1bf9396225/MSSM_310_NeuN_pl.cram
# 3083cec0-f58d-4e9b-b9c3-569e4cf63d14/PITT_098_NeuN_pl.cram
# 311fcda2-22f5-477c-80fa-ece521370b9a/MSSM_065_NeuN_pl.cram
# 39f01b27-1234-4db5-b94b-977056bec5c3/PITT_017_NeuN_pl.cram
# 40b4084d-0791-42a2-ba1d-2c9c8dc40e7c/PITT_072_NeuN_pl.cram
# 41f65c93-c079-4123-b08b-9a9355695615/MSSM_305_NeuN_pl.cram
# 475392a7-5f20-4a07-8694-9dc86a677032/MSSM_033_NeuN_pl.cram
# 496db54a-a071-42c6-85c3-788cb10e081b/MSSM_291_NeuN_pl.cram
# 4ac9bef6-ae37-4d37-a992-458702e7bf0e/MSSM_193_NeuN_pl.cram
# 4b81dcd7-520a-4e31-978f-d5c41f061143/MSSM_321_NeuN_pl.cram
# 5229ec83-c2eb-4f44-8d2b-f688b476bbda/MSSM_027_NeuN_pl.cram
# 56eba15a-172a-41f8-95c1-341db7b77bbb/MSSM_178_NeuN_pl.cram
# 58cff892-6fac-4d14-9c78-45f997d825c6/PITT_020_NeuN_pl.cram
# 58db3a23-53a4-4f47-baf1-26919d9be629/MSSM_287_NeuN_pl.cram
# 590d1603-7612-4a8d-a9d4-8168fac16840/MSSM_158_NeuN_pl.cram
# 608d0b28-3e81-4433-9653-7a55b93398d8/MSSM_405_NeuN_pl.cram
# 66475c06-2559-4e16-a846-fe867fa04947/MSSM_164_NeuN_pl.cram
# 684009c7-a58f-45fd-971e-46f46a5eafb8/MSSM_162_NeuN_pl.cram
# 6c489550-34e6-441a-9349-4b7915840dac/MSSM_362_NeuN_pl.cram
# 70a51997-4d3f-4250-bb43-e3e1ca62a6b9/MSSM_180_NeuN_pl.cram
# 778a9eba-44ee-4d35-a634-39b64d0e4474/MSSM_130_NeuN_pl.cram
# 80939e0b-a905-4d95-a921-6f79ea9b10af/PITT_004_NeuN_pl.cram
# 844f5f33-12d3-41dd-afad-9551ca4957e5/MSSM_299_NeuN_pl.cram
# 85262ec9-d3a4-49eb-bbfb-e93fa3e20ff0/MSSM_370_NeuN_pl.cram
# 8beeca04-a574-4662-b720-6df8ed2bb479/MSSM_297_NeuN_pl.cram
# 8ca85c9c-3234-425d-88f2-b15395987a0e/PITT_036_NeuN_pl.cram
# 8fff721e-530b-400b-94f1-74b1908898ff/MSSM_308_NeuN_pl.cram
# 94947a51-482a-4dc9-b1c1-f06f68c8c5d5/MSSM_352_NeuN_pl.cram
# 97ab0e14-d1c3-49df-9772-ba7fdc025474/MSSM_192_NeuN_pl.cram
# 9a49aa6b-08a9-45c4-880a-2c039c4b1877/MSSM_293_NeuN_pl.cram
# 9cbb7990-ab6b-4b59-a678-0ba5d8b9d321/MSSM_069_NeuN_pl.cram
# a332ba97-9b2a-4460-b510-f8bc43e87a88/MSSM_304_NeuN_pl.cram
# a362cca4-eee9-4655-a853-b871367bd9d4/MSSM_201_NeuN_pl.cram
# a4767744-7fc6-492c-9947-2eb5f2300c6e/PITT_060_NeuN_pl.cram
# a58d6e47-cb20-493e-974c-4a46d2d4f017/PITT_113_NeuN_pl.cram
# af069550-3c69-4e3a-bbb3-48d532d2c21c/MSSM_056_NeuN_pl.cram
# b007d597-e74b-411f-8ca6-b859e897ef65/MSSM_222_NeuN_pl.cram
# b03511a8-84aa-4646-8ef6-aca02fe0bd51/MSSM_366_NeuN_pl.cram
# b0385716-8277-4cbf-baa1-e5755f55f5bc/PITT_117_NeuN_pl.cram
# b03d0089-8b3d-4517-800f-37faafb2f3b1/MSSM_116_NeuN_pl.cram
# b0a50c8c-f8f1-41c4-8a80-fe437f497c20/MSSM_273_NeuN_pl.cram
# b6026d3d-cb42-4dd4-a3da-ef0cdedf423f/PITT_101_NeuN_pl.cram
# b74deec4-7dfb-479c-9959-bd3dbbb02edb/MSSM_339_NeuN_pl.cram
# b859ad79-6456-47e9-9932-806c7194e23b/MSSM_142_NeuN_pl.cram
# b941b2c3-d361-4280-86d9-ca9dcdb8e11d/MSSM_379_NeuN_pl.cram
# bc37b18a-a98d-4dac-ba6c-c461918be6c5/MSSM_364_NeuN_pl.cram
# c2012208-b9a8-4a4d-a3c5-dfbbdb8559e5/PITT_052_NeuN_pl.cram
# c7edc0ec-afc3-40f1-8ee8-b82eb8f33e87/MSSM_168_NeuN_pl.cram
# c8d6ee59-3aad-4c8e-9370-b3e7b0911b47/MSSM_415_NeuN_pl.cram
# c95ffc62-35e0-45e3-80e5-feacdd9a5a67/MSSM_265_NeuN_pl.cram
# ca685446-d65d-4b93-b883-b19082f997e3/MSSM_327_NeuN_pl.cram
# cc9aa3d6-2820-4b4f-9183-bfdf0040dabc/MSSM_099_NeuN_pl.cram
# d3988ef5-cdb0-4434-a033-2bbb11ac09a4/MSSM_363_NeuN_pl.cram
# d612aa5b-9d92-4367-bd35-c53374e5de49/MSSM_227_NeuN_pl.cram
# d65a4ba7-1d8d-4bc2-8746-cf734dc38991/MSSM_254_NeuN_pl.cram
# d7258196-3444-40cc-8888-bbfed52d959a/MSSM_097_NeuN_pl.cram
# d98961ae-eef8-4eb3-8be8-5a79f9fda507/MSSM_063_NeuN_pl.cram
# da84e438-1cd1-4073-92b6-a5902e1843ee/MSSM_161_NeuN_pl.cram
# dbf40a34-b936-486c-b9e4-08f7fbbd66c9/MSSM_406_NeuN_pl.cram
# dd676e69-f744-4dc0-ba43-20ae3b34b639/MSSM_346_NeuN_pl.cram
# deaf32ce-3907-4279-9e3d-28ba8e30e758/MSSM_343_NeuN_pl.cram
# dfd32483-1e1a-452b-9650-3e74015ceb2b/MSSM_224_NeuN_pl.cram
# e0a79e64-02f6-4b2b-81cf-5474f5dcf51d/MSSM_100_NeuN_pl.cram
# e103ed4b-0822-4d41-ae8a-9004347572de/MSSM_331_NeuN_pl.cram
# e55eb946-1335-4dd5-a26b-85d74b5e3a36/MSSM_055_NeuN_pl.cram
# e84c582b-41f6-4441-9a4e-06c27dada0da/MSSM_295_NeuN_pl.cram
# ec796df7-6013-4e3d-b483-ee82a448fe64/MSSM_211_NeuN_pl.cram
# ee503300-a0cb-49d3-a272-19e77611b88c/MSSM_372_NeuN_pl.cram
# eeb56e33-d0d3-492e-b84b-40aee8ab3788/PITT_082_NeuN_pl.cram
# fa4fdccd-5c3d-46be-b704-048a6d91bb6c/MSSM_213_NeuN_pl.cram
# Press the "Enter" key to specify directory/directories OR an s3 location by entering -s3 <bucket name> to locate your associated files:----
# flagstat.txt
# Running NDATools Version 0.2.3
# Opening log: /home/attila/NDAValidationResults/debug_log_20210222T210200.txt
#
# Validating files...
# Validation report output to: /home/attila/NDAValidationResults/validation_results_20210222T210200.csv
# Warnings output to: /home/attila/NDAValidationResults/validation_results_20210222T210200.csv
#
# All files have finished validating.
#
# The following files passed validation:
# UUID 83ea4ed1-db1a-4722-83fe-f83fdc810d76: nichd_btb02-2021-02-02.csv
# UUID 365f2332-a98f-4c69-ad20-fd683cfc5ab2: genomics_sample03-flagstat.txt.csv
# UUID f8e88889-08af-4c34-9d6b-5e6b326580ad: genomics_subject02-2021-02-02.csv
#
# Searching for associated files...
#
#  Your user does NOT have access to the following buckets. Please review the bucket and/or your AWS credentials and try again.
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
#
#  You must make sure all associated files listed in your validation file are located in the specified directory or AWS bucket. Associated file not found in specified directory:
#
# 05636b90-4122-4e38-af77-b5889cf86a4f/MSSM_164_NeuN_pl.flagstat.txt
# 0663f836-b86e-4f37-9a89-784931dfe08d/MSSM_339_NeuN_pl.flagstat.txt
# 0c3f5d58-de15-4747-820a-bb21e44c0290/MSSM_406_NeuN_pl.flagstat.txt
# 0d62253a-4158-4976-9f6a-60a38de20b63/MSSM_180_NeuN_pl.flagstat.txt
# 0e66da27-3dc1-4d03-8064-6d1041a8c54e/MSSM_309_NeuN_pl.flagstat.txt
# 12090361-4a02-4c2f-8efd-8d3691cedaa8/MSSM_343_NeuN_pl.flagstat.txt
# 12c3ac58-780f-4beb-80d5-e3e10bd533d3/MSSM_269_NeuN_pl.flagstat.txt
# 1ea17362-f7ea-4374-98d3-cdb908e802b9/MSSM_291_NeuN_pl.flagstat.txt
# 1f632474-2522-4554-9427-0058e32d20cd/MSSM_100_NeuN_pl.flagstat.txt
# 20068504-c347-494c-a6e7-d9ff0e914aca/MSSM_379_NeuN_pl.flagstat.txt
# 20c4d81a-3c27-46bd-b731-7bde7ed98bb6/MSSM_321_NeuN_pl.flagstat.txt
# 2fda7b2c-f26c-4a9c-9ba3-6d4dd43a3e6d/MSSM_340_NeuN_pl.flagstat.txt
# 31409a18-d18d-49db-9abe-7bd9c30c347d/MSSM_310_NeuN_pl.flagstat.txt
# 34cb53c7-d39a-44fa-bdaf-d84086be95b7/PITT_050_NeuN_pl.flagstat.txt
# 36b42479-8e09-43e5-95a3-9653dc736a9f/MSSM_162_NeuN_pl.flagstat.txt
# 3dbe94d7-ed6b-4094-b5bc-fe7ee0d8a69f/MSSM_116_NeuN_pl.flagstat.txt
# 3eeac5ac-2512-404b-bf07-7626b1f55924/MSSM_363_NeuN_pl.flagstat.txt
# 40548e7e-05fc-4440-9cf7-b8ce1a7c6afb/MSSM_362_NeuN_pl.flagstat.txt
# 486224c9-a09b-4a1f-827f-d97b8879046c/MSSM_158_NeuN_pl.flagstat.txt
# 4f351ada-15ea-46cb-a93b-369d4f54035b/PITT_060_NeuN_pl.flagstat.txt
# 5080dddb-c1d7-4d0f-9373-c6f0a6e862a6/MSSM_370_NeuN_pl.flagstat.txt
# 515da97d-2a84-498e-981b-08134b940789/MSSM_097_NeuN_pl.flagstat.txt
# 5194b803-78cb-4026-a106-a986f2d30e65/MSSM_372_NeuN_pl.flagstat.txt
# 5418ff03-acac-4d2b-86c5-401a133eb8b0/MSSM_293_NeuN_pl.flagstat.txt
# 571b58f3-9cc7-479d-b744-0315d2e28ebb/PITT_117_NeuN_pl.flagstat.txt
# 59560133-f896-4c89-a28a-10e7cbd207b1/MSSM_033_NeuN_pl.flagstat.txt
# 5c5e146a-d9b5-4e2b-8e0b-b187179cb086/MSSM_222_NeuN_pl.flagstat.txt
# 5eacdebc-ffe3-4e94-931d-419a8fc1e310/MSSM_331_NeuN_pl.flagstat.txt
# 5f4837d6-7907-46e8-828f-d8c62e0f31d1/MSSM_063_NeuN_pl.flagstat.txt
# 67fe18c5-a816-4405-8e61-8d19977bd223/MSSM_287_NeuN_pl.flagstat.txt
# 6f8f1577-d30f-4046-b576-8dc5d0b6584f/MSSM_405_NeuN_pl.flagstat.txt
# 738d63b9-d794-4475-ac91-322d6b5adbcc/PITT_101_NeuN_pl.flagstat.txt
# 787801a2-4479-4566-bb0d-605cef16f03e/MSSM_178_NeuN_pl.flagstat.txt
# 78dfd0c5-2700-47c2-af21-99b59a07b142/MSSM_295_NeuN_pl.flagstat.txt
# 858d600d-0ea5-448f-91b5-1fabc2d14703/MSSM_213_NeuN_pl.flagstat.txt
# 87a5a663-0844-43a4-bc42-7368ab24c77d/MSSM_308_NeuN_pl.flagstat.txt
# 87b505f9-6f79-4760-bfbb-1272b6fd2639/MSSM_199_NeuN_pl.flagstat.txt
# 88a088ab-736c-43af-9825-2f3b7c4979e4/MSSM_192_NeuN_pl.flagstat.txt
# 8a9e837d-41dc-4b33-83b4-dbb66cfb1259/PITT_052_NeuN_pl.flagstat.txt
# 8bb50aea-7bd7-4c01-b618-8dbe8f1d39f3/MSSM_055_NeuN_pl.flagstat.txt
# 8c8ef44e-da7e-4cc3-9219-904b9f727fe1/MSSM_069_NeuN_pl.flagstat.txt
# 8ed6c616-8daf-482b-93ed-ef630d3ef81b/MSSM_346_NeuN_pl.flagstat.txt
# 90a49761-eea2-41cd-aaf5-013de07d5a9f/MSSM_366_NeuN_pl.flagstat.txt
# 92863eda-dc40-43fd-b248-10767c6caa31/PITT_024_NeuN_pl.flagstat.txt
# 930839c5-d035-4a67-8e1f-4889c0f6f06d/MSSM_297_NeuN_pl.flagstat.txt
# 93f637b1-76ce-4220-842c-1c358b090466/MSSM_338_NeuN_pl.flagstat.txt
# 941c730b-0c8c-4338-bd46-ad573fb51ff5/MSSM_266_NeuN_pl.flagstat.txt
# 9a99912d-203f-4803-9f35-9bc8d32811b2/MSSM_265_NeuN_pl.flagstat.txt
# a064f9b1-7e84-4dfc-92de-539362c1d15b/MSSM_304_NeuN_pl.flagstat.txt
# a1769875-0a53-4b23-8d4b-0697801841fa/MSSM_348_NeuN_pl.flagstat.txt
# a4d3474b-cb45-4cf4-800a-7eb603ab2a37/MSSM_224_NeuN_pl.flagstat.txt
# a998affa-34c4-4345-abec-f98f498c31b7/MSSM_065_NeuN_pl.flagstat.txt
# a9c3690d-9007-42a8-bfef-dd0aaf36d287/PITT_007_NeuN_pl.flagstat.txt
# aad6116d-8dfe-41f6-ab9e-2ba7e3fe37b3/MSSM_130_NeuN_pl.flagstat.txt
# b378f483-4681-4173-97ea-42bd2bdeed4f/MSSM_327_NeuN_pl.flagstat.txt
# b589eb4f-efea-4d4e-802c-dd688428b1d1/PITT_082_NeuN_pl.flagstat.txt
# b5a6a1c8-ea4f-47d8-b3a6-e7be299b2453/PITT_036_NeuN_pl.flagstat.txt
# bf6ac91c-5151-4ec0-bc31-0c491d1de3b8/MSSM_415_NeuN_pl.flagstat.txt
# c7214a85-d29a-4c6d-b7da-23bdf229130b/MSSM_193_NeuN_pl.flagstat.txt
# c7d9abb7-293f-44a7-a329-fe4b3197e8de/MSSM_142_NeuN_pl.flagstat.txt
# ce358019-5e03-4c83-ad0a-cc97ec19af16/MSSM_211_NeuN_pl.flagstat.txt
# ce440615-c170-4c96-bdcc-c66da6d9f02f/PITT_113_NeuN_pl.flagstat.txt
# cf503b4a-7eae-4f18-945b-30dce3c0b8ce/MSSM_227_NeuN_pl.flagstat.txt
# d0f96ec4-d96a-4579-8d3c-99b77fe8fbe5/MSSM_161_NeuN_pl.flagstat.txt
# d4adf37b-2f34-43ef-ae47-b224d1259cee/PITT_072_NeuN_pl.flagstat.txt
# d9c1525a-968b-4def-a263-726718693a8a/MSSM_201_NeuN_pl.flagstat.txt
# daac454a-6736-46bb-92f2-3c5a378ceefa/PITT_004_NeuN_pl.flagstat.txt
# dad60783-7716-4f1a-bb09-d317cce79457/MSSM_352_NeuN_pl.flagstat.txt
# e1f367bb-c395-403f-8499-10330d34b689/PITT_020_NeuN_pl.flagstat.txt
# e3c0a1f3-43fa-472d-b77a-a37c593180f9/PITT_071_NeuN_pl.flagstat.txt
# e4f0ef8e-a2d3-4b2e-97f6-a2ada8eac14b/MSSM_364_NeuN_pl.flagstat.txt
# e7b775aa-777e-48f8-95ed-75859592e1f8/MSSM_168_NeuN_pl.flagstat.txt
# e82266f4-b4e8-466e-b01a-2a95530e4ebe/PITT_098_NeuN_pl.flagstat.txt
# e949a963-02fe-4284-afc2-ea4e5ce3c7e1/MSSM_299_NeuN_pl.flagstat.txt
# eab64d26-c85f-4bfb-a82e-9324af660620/MSSM_099_NeuN_pl.flagstat.txt
# eba3fecd-1420-42de-a34f-e5313f503ea9/MSSM_027_NeuN_pl.flagstat.txt
# f8b3ac37-94c6-4253-a689-7c5328e4368e/PITT_017_NeuN_pl.flagstat.txt
# f91a9207-9b6c-4e33-ae2f-a3c9f8d01391/MSSM_254_NeuN_pl.flagstat.txt
# fc2023c5-0442-4d74-a28a-2dc84e2c5a5a/MSSM_305_NeuN_pl.flagstat.txt
# fda560b2-0be4-47bc-bc21-ad4ff10fb62a/MSSM_273_NeuN_pl.flagstat.txt
# fe9baf74-9c1d-49f2-895d-3b6de6b08206/MSSM_056_NeuN_pl.flagstat.txt
# Press the "Enter" key to specify directory/directories OR an s3 location by entering -s3 <bucket name> to locate your associated files:----
# ploidy_2.vcf.gz
# Running NDATools Version 0.2.3
# Opening log: /home/attila/NDAValidationResults/debug_log_20210222T210204.txt
#
# Validating files...
# Validation report output to: /home/attila/NDAValidationResults/validation_results_20210222T210204.csv
# Warnings output to: /home/attila/NDAValidationResults/validation_results_20210222T210204.csv
#
# All files have finished validating.
#
# The following files passed validation:
# UUID 5fa2940c-cdc0-4814-b066-88c5718a915b: genomics_sample03-ploidy_2.vcf.gz.csv
# UUID 52ab9328-f49f-432d-84ad-8bded3c98ae8: genomics_subject02-2021-02-02.csv
# UUID 358c31e2-4833-43ea-9860-c58237e0bd66: nichd_btb02-2021-02-02.csv
#
# Searching for associated files...
#
#  Your user does NOT have access to the following buckets. Please review the bucket and/or your AWS credentials and try again.
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
#
#  You must make sure all associated files listed in your validation file are located in the specified directory or AWS bucket. Associated file not found in specified directory:
#
# 0373b395-1f9c-47fd-a4a5-1126c19c43db/MSSM_321_NeuN_pl.ploidy_2.vcf.gz
# 0f86b67e-4f18-4cd9-b285-c575941dd965/MSSM_366_NeuN_pl.ploidy_2.vcf.gz
# 183f6a89-8b0f-41e8-81fd-677fe713423e/MSSM_161_NeuN_pl.ploidy_2.vcf.gz
# 1cf5d72d-cf1b-4b3c-9c34-867d96d3ec2c/MSSM_227_NeuN_pl.ploidy_2.vcf.gz
# 23471367-6173-47f3-a335-d586a6d2e5a3/MSSM_199_NeuN_pl.ploidy_2.vcf.gz
# 269e9962-268e-45cc-8236-aa2692401c07/PITT_117_NeuN_pl.ploidy_2.vcf.gz
# 2864716c-99f7-4dcb-ac62-e0d52c69f65d/MSSM_213_NeuN_pl.ploidy_2.vcf.gz
# 28fb20e9-466e-4325-b35b-b98ee7b13894/MSSM_406_NeuN_pl.ploidy_2.vcf.gz
# 29dacef4-1e48-419c-bfcb-736247a34ac9/PITT_036_NeuN_pl.ploidy_2.vcf.gz
# 31202131-4a16-4bd5-828a-7cd0f9dba18b/MSSM_362_NeuN_pl.ploidy_2.vcf.gz
# 35573711-71df-40ab-a5b2-04dd5e8968f1/MSSM_291_NeuN_pl.ploidy_2.vcf.gz
# 3601914d-6cb3-419b-9920-ecb3159aecfe/MSSM_180_NeuN_pl.ploidy_2.vcf.gz
# 36473be7-891f-45bb-999e-559ef8130c82/MSSM_192_NeuN_pl.ploidy_2.vcf.gz
# 36c0dd4d-27e1-4758-9a73-3d4c7cf59c65/MSSM_343_NeuN_pl.ploidy_2.vcf.gz
# 39437bd2-451c-4e19-bb0c-b89a1017b9df/MSSM_033_NeuN_pl.ploidy_2.vcf.gz
# 39df4c48-8984-4605-a0de-b9b9a71a25fb/MSSM_168_NeuN_pl.ploidy_2.vcf.gz
# 3dc988c9-fbb2-4751-8343-5958dbc3c96f/MSSM_178_NeuN_pl.ploidy_2.vcf.gz
# 408a3f52-58b4-420a-ad84-e8386444fd93/MSSM_254_NeuN_pl.ploidy_2.vcf.gz
# 42c2375c-b380-4488-b05c-21f4905845d4/MSSM_287_NeuN_pl.ploidy_2.vcf.gz
# 43fb4830-c4cc-469d-a24e-517cf127f176/MSSM_063_NeuN_pl.ploidy_2.vcf.gz
# 447cb870-f455-4fc1-807a-2ff6f1998579/PITT_004_NeuN_pl.ploidy_2.vcf.gz
# 48eac1ad-33fa-4412-8d42-76d942fa8937/PITT_113_NeuN_pl.ploidy_2.vcf.gz
# 49dd57b6-dbde-4e0a-a617-a4fcbb886a81/MSSM_116_NeuN_pl.ploidy_2.vcf.gz
# 505d2110-10b1-46f9-bbdd-0a8f224aa270/MSSM_348_NeuN_pl.ploidy_2.vcf.gz
# 519b405f-f27b-4405-b71b-8f0d419928bb/MSSM_308_NeuN_pl.ploidy_2.vcf.gz
# 586121b7-f109-425e-a634-0c712eafb466/MSSM_211_NeuN_pl.ploidy_2.vcf.gz
# 5cc5c9ab-85f4-4057-9846-d171d4d4f5c1/MSSM_056_NeuN_pl.ploidy_2.vcf.gz
# 5ccf8aee-e8cf-4a75-8123-a45a0939cb12/MSSM_100_NeuN_pl.ploidy_2.vcf.gz
# 5f4c1f47-70a1-4b0b-be10-12bb847c7189/MSSM_222_NeuN_pl.ploidy_2.vcf.gz
# 5f8a2b71-ae3e-4a33-99ce-915b2a522b9e/MSSM_055_NeuN_pl.ploidy_2.vcf.gz
# 63f62b33-4eb1-4391-841e-0205c37df474/PITT_007_NeuN_pl.ploidy_2.vcf.gz
# 677ef04e-23a5-4ca5-b3fd-2ac3164bd6cd/MSSM_224_NeuN_pl.ploidy_2.vcf.gz
# 684a6775-6b83-49ef-87a7-c61863ff62d5/PITT_071_NeuN_pl.ploidy_2.vcf.gz
# 68fb6151-5efc-47c9-9dca-a745ed131907/MSSM_379_NeuN_pl.ploidy_2.vcf.gz
# 6935f513-1cde-4cc8-b805-ec028fb1f0ee/MSSM_130_NeuN_pl.ploidy_2.vcf.gz
# 6a62fc5e-ac8a-4f4e-9ef8-767f2565927c/MSSM_310_NeuN_pl.ploidy_2.vcf.gz
# 6a684fd1-23d5-464d-b14a-28c08b74f86f/MSSM_164_NeuN_pl.ploidy_2.vcf.gz
# 76b87ca7-f03d-47f6-bdce-9118e46f38cd/MSSM_297_NeuN_pl.ploidy_2.vcf.gz
# 78bc7d38-252b-4571-b000-4ffb3c989327/MSSM_339_NeuN_pl.ploidy_2.vcf.gz
# 7be12af1-793a-49c9-bf34-661a3ba55233/MSSM_295_NeuN_pl.ploidy_2.vcf.gz
# 7c45a720-9a01-4f34-87c7-e580122d40a8/MSSM_162_NeuN_pl.ploidy_2.vcf.gz
# 7edffdf3-c51e-4241-bc4e-d7bc681d5505/PITT_024_NeuN_pl.ploidy_2.vcf.gz
# 805f5146-6756-4b67-bdc2-5851a36f2ad9/MSSM_193_NeuN_pl.ploidy_2.vcf.gz
# 8601306d-b551-437a-a348-6a6e83da25d2/MSSM_142_NeuN_pl.ploidy_2.vcf.gz
# 89c43df5-ad2e-4883-8265-3e4e2998c63e/MSSM_372_NeuN_pl.ploidy_2.vcf.gz
# 8b4bb995-4c12-4a4a-9b82-56d745704697/MSSM_304_NeuN_pl.ploidy_2.vcf.gz
# 92dbf4c5-5340-4633-b181-bdfacfb535fb/MSSM_346_NeuN_pl.ploidy_2.vcf.gz
# 9341f7b4-f7ca-43f7-9b12-f220134fdac0/PITT_060_NeuN_pl.ploidy_2.vcf.gz
# 9449ca65-08f4-4f22-a4d2-952d4787f559/MSSM_299_NeuN_pl.ploidy_2.vcf.gz
# 9933fb08-8a52-453e-a0b9-30cb79e733fb/PITT_101_NeuN_pl.ploidy_2.vcf.gz
# 9a2cbc28-131a-497e-b433-84aedd1f8f6a/MSSM_265_NeuN_pl.ploidy_2.vcf.gz
# 9c20362f-15c0-49ed-b89e-2d4ffdc049e0/MSSM_327_NeuN_pl.ploidy_2.vcf.gz
# 9fe7fb04-c9c2-4529-9ed8-f1130bdac518/PITT_050_NeuN_pl.ploidy_2.vcf.gz
# a4eae51f-3f3a-42b9-a006-3cc5d502e6fa/MSSM_331_NeuN_pl.ploidy_2.vcf.gz
# a5b8eaa4-5d2c-476e-9ba5-9895e1c9fd7a/MSSM_352_NeuN_pl.ploidy_2.vcf.gz
# a8193498-b287-4451-adb1-be0e2cfb74ef/MSSM_065_NeuN_pl.ploidy_2.vcf.gz
# ac397af8-96d9-44c0-aac9-ef34906ad01b/MSSM_340_NeuN_pl.ploidy_2.vcf.gz
# ae544583-77e9-4b3a-a27f-983adbd41864/MSSM_266_NeuN_pl.ploidy_2.vcf.gz
# af58eb0b-e9a8-4044-a416-2c2fcbca3f22/MSSM_158_NeuN_pl.ploidy_2.vcf.gz
# b44f1396-8b54-4a74-9678-02487fcdffd1/PITT_082_NeuN_pl.ploidy_2.vcf.gz
# b48141d0-0f95-4edc-b8e7-93303d8fd596/MSSM_069_NeuN_pl.ploidy_2.vcf.gz
# b54fd27f-11cf-4c5e-9911-454e7cf35296/MSSM_201_NeuN_pl.ploidy_2.vcf.gz
# b7d1ac32-52a7-4070-8316-b819b84e7f52/MSSM_027_NeuN_pl.ploidy_2.vcf.gz
# ba5a6a48-4630-47c8-ae09-8da0dad693ec/MSSM_309_NeuN_pl.ploidy_2.vcf.gz
# bb08079e-c353-4ab2-8328-49cea122670f/MSSM_293_NeuN_pl.ploidy_2.vcf.gz
# c204df9c-3bb4-497e-b0b9-e9f9221bd7ab/PITT_020_NeuN_pl.ploidy_2.vcf.gz
# c577f613-a0b7-40ff-92e6-1c647c711c51/PITT_017_NeuN_pl.ploidy_2.vcf.gz
# c866fd15-dd3d-4657-9935-6cbed37755b0/MSSM_338_NeuN_pl.ploidy_2.vcf.gz
# c96c5b1b-0ef0-4791-8800-fd9941c0edaf/MSSM_269_NeuN_pl.ploidy_2.vcf.gz
# d7c2d9a4-47eb-4144-9bd7-8b6d98c89b89/MSSM_370_NeuN_pl.ploidy_2.vcf.gz
# d9e76a96-680c-4da0-b277-7e8a87eb0f8b/MSSM_415_NeuN_pl.ploidy_2.vcf.gz
# dfd50e3b-4ef7-461c-bc6b-2910984ff058/MSSM_273_NeuN_pl.ploidy_2.vcf.gz
# e1c8ebcd-b5b3-47c4-b542-27f090135604/MSSM_099_NeuN_pl.ploidy_2.vcf.gz
# e9b48e05-6a0b-4742-abb5-b61d7da5e9ec/MSSM_363_NeuN_pl.ploidy_2.vcf.gz
# efe8c064-ad59-4be2-b79f-4f59d222ea42/MSSM_405_NeuN_pl.ploidy_2.vcf.gz
# f70c5831-09f5-42c9-a5ad-a68c5476644c/MSSM_305_NeuN_pl.ploidy_2.vcf.gz
# f8178b4a-345f-41ad-8933-2c01bd8c17a3/MSSM_097_NeuN_pl.ploidy_2.vcf.gz
# fa2d74f2-fca9-43c3-8aae-56f8e84bf54e/PITT_072_NeuN_pl.ploidy_2.vcf.gz
# fbde2d10-98ad-45b2-9edd-58d31c53e269/PITT_052_NeuN_pl.ploidy_2.vcf.gz
# ff86d2bc-f507-4070-ba30-5eb29d5c29da/MSSM_364_NeuN_pl.ploidy_2.vcf.gz
# ff8b572f-c5e5-48aa-b9ba-d42d320b3076/PITT_098_NeuN_pl.ploidy_2.vcf.gz
# Press the "Enter" key to specify directory/directories OR an s3 location by entering -s3 <bucket name> to locate your associated files:----
# ploidy_2.vcf.gz.tbi
# Running NDATools Version 0.2.3
# Opening log: /home/attila/NDAValidationResults/debug_log_20210222T210209.txt
#
# Validating files...
# Validation report output to: /home/attila/NDAValidationResults/validation_results_20210222T210209.csv
# Warnings output to: /home/attila/NDAValidationResults/validation_results_20210222T210209.csv
#
# All files have finished validating.
#
# The following files passed validation:
# UUID 92674840-5528-4651-8e9d-3f8797b7620c: nichd_btb02-2021-02-02.csv
# UUID b93d535a-ed30-42a9-9884-d23f053cfb75: genomics_subject02-2021-02-02.csv
# UUID eaeb7ee0-5fa6-43dc-b0fa-9d459bf52072: genomics_sample03-ploidy_2.vcf.gz.tbi.csv
#
# Searching for associated files...
#
#  Your user does NOT have access to the following buckets. Please review the bucket and/or your AWS credentials and try again.
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
#
#  You must make sure all associated files listed in your validation file are located in the specified directory or AWS bucket. Associated file not found in specified directory:
#
# 0037c3d4-949e-4cee-be10-2d3e9e0a4d09/MSSM_027_NeuN_pl.ploidy_2.vcf.gz.tbi
# 00f25616-03b2-4c68-a01c-53165c989c3f/MSSM_178_NeuN_pl.ploidy_2.vcf.gz.tbi
# 024d9c9b-6e9f-48fa-92be-5ff9bcb4925c/MSSM_213_NeuN_pl.ploidy_2.vcf.gz.tbi
# 04901003-47e3-4e7d-85d9-dfdf16310deb/PITT_098_NeuN_pl.ploidy_2.vcf.gz.tbi
# 0fb9da83-81ca-45e4-85fc-15d68b7280a7/MSSM_287_NeuN_pl.ploidy_2.vcf.gz.tbi
# 10933fd1-a4cf-44e8-b03e-a7b0c41c3700/MSSM_406_NeuN_pl.ploidy_2.vcf.gz.tbi
# 126b5502-3fe0-4f91-8717-e1b9374b22d0/PITT_071_NeuN_pl.ploidy_2.vcf.gz.tbi
# 137078cb-26ca-4d97-941d-6eb5c5ef12f5/PITT_004_NeuN_pl.ploidy_2.vcf.gz.tbi
# 15cf98a7-261b-4cff-864b-44647c38d9e0/MSSM_348_NeuN_pl.ploidy_2.vcf.gz.tbi
# 185f2037-f886-4d1b-89f5-34ccdbb7fd11/PITT_052_NeuN_pl.ploidy_2.vcf.gz.tbi
# 194dafc4-5ee5-4da1-be37-7c0a22f29bd4/MSSM_142_NeuN_pl.ploidy_2.vcf.gz.tbi
# 1ee997d2-65c0-4e60-ae5e-5a02ff6e03c1/MSSM_372_NeuN_pl.ploidy_2.vcf.gz.tbi
# 212d320b-92c8-4013-8105-4931b9f7a997/MSSM_309_NeuN_pl.ploidy_2.vcf.gz.tbi
# 2937b9cb-4943-4bf1-9a66-51fb309e2d08/MSSM_346_NeuN_pl.ploidy_2.vcf.gz.tbi
# 293b5fb0-4624-4c84-90a0-96a119b759e7/MSSM_299_NeuN_pl.ploidy_2.vcf.gz.tbi
# 2eda6c31-7eeb-4012-a657-fe0662f206fe/MSSM_321_NeuN_pl.ploidy_2.vcf.gz.tbi
# 2f8a5e28-024f-4c33-98e4-e90ba9cd3e98/MSSM_254_NeuN_pl.ploidy_2.vcf.gz.tbi
# 34f7ac9c-1832-48e8-bcab-2fa19e0bb5a8/MSSM_415_NeuN_pl.ploidy_2.vcf.gz.tbi
# 37b83cc5-3b18-4fed-80d4-d81ffc234766/PITT_007_NeuN_pl.ploidy_2.vcf.gz.tbi
# 38fb9a45-a546-40d3-9463-ddade9812cc3/MSSM_069_NeuN_pl.ploidy_2.vcf.gz.tbi
# 414e01cb-724d-411b-9963-3aa530f41ae2/MSSM_338_NeuN_pl.ploidy_2.vcf.gz.tbi
# 4584cc30-2197-426b-a8e2-0d0a9efd9bba/PITT_020_NeuN_pl.ploidy_2.vcf.gz.tbi
# 45d4c2cc-186d-4750-9730-f50b7d6d4ab4/MSSM_327_NeuN_pl.ploidy_2.vcf.gz.tbi
# 47dd7e83-7c7f-4cc9-80c7-adca0f515f08/MSSM_097_NeuN_pl.ploidy_2.vcf.gz.tbi
# 57402f3b-1d0b-4e31-b509-f4cce75b2d07/PITT_036_NeuN_pl.ploidy_2.vcf.gz.tbi
# 647b38c7-bc90-4a52-9d8f-032346c311a5/MSSM_100_NeuN_pl.ploidy_2.vcf.gz.tbi
# 69155c3a-dae1-4828-9d24-c254d2b66170/MSSM_364_NeuN_pl.ploidy_2.vcf.gz.tbi
# 705103c7-96d1-406c-8d9d-ecf87f935202/MSSM_065_NeuN_pl.ploidy_2.vcf.gz.tbi
# 7158d01a-91f7-4929-92cb-d3e98a64b75b/PITT_101_NeuN_pl.ploidy_2.vcf.gz.tbi
# 7292ea83-78d7-4b4d-b21a-e8014f4b84e0/MSSM_304_NeuN_pl.ploidy_2.vcf.gz.tbi
# 7ab57a2d-dee4-4ff7-957c-7d23d6e60b95/PITT_050_NeuN_pl.ploidy_2.vcf.gz.tbi
# 7d5cc8ee-506e-4ca3-90c2-f8ce00ba505e/MSSM_291_NeuN_pl.ploidy_2.vcf.gz.tbi
# 80e3b58a-c573-4496-bd27-2416d6fdfaf3/PITT_117_NeuN_pl.ploidy_2.vcf.gz.tbi
# 83ae1481-ea31-4bcd-b83c-b447db8f712d/MSSM_362_NeuN_pl.ploidy_2.vcf.gz.tbi
# 83f62c13-07d0-4859-91ff-a7016751b18f/MSSM_352_NeuN_pl.ploidy_2.vcf.gz.tbi
# 8dfae853-344f-4cb4-bfad-1577daf1bfd1/MSSM_222_NeuN_pl.ploidy_2.vcf.gz.tbi
# 8fe03d4d-5e9c-4264-90a2-7fa63b8de6c4/MSSM_363_NeuN_pl.ploidy_2.vcf.gz.tbi
# 94b4df28-cceb-4110-b329-2713c0f51740/MSSM_295_NeuN_pl.ploidy_2.vcf.gz.tbi
# 97705593-5aa4-4fad-9ca5-ffd915f165d5/MSSM_308_NeuN_pl.ploidy_2.vcf.gz.tbi
# 99ec21fb-2baf-4704-92f9-791a28f8e669/MSSM_180_NeuN_pl.ploidy_2.vcf.gz.tbi
# a325f5a3-2ad9-42c5-aef5-2029b00e9b7f/MSSM_063_NeuN_pl.ploidy_2.vcf.gz.tbi
# a6ff2132-d3f1-4555-be1d-1cf2f87c8d43/MSSM_116_NeuN_pl.ploidy_2.vcf.gz.tbi
# a88093de-b598-4eb0-be09-577906ffb27d/MSSM_055_NeuN_pl.ploidy_2.vcf.gz.tbi
# aac206a6-e0a7-4d86-91cb-10e42538e9cb/MSSM_370_NeuN_pl.ploidy_2.vcf.gz.tbi
# ab7ae915-5ff3-4fea-b65a-9d75b6040f6e/MSSM_310_NeuN_pl.ploidy_2.vcf.gz.tbi
# ac4f90c0-4e4a-4ef6-9685-a16a8b37ee4c/PITT_082_NeuN_pl.ploidy_2.vcf.gz.tbi
# ae2c4967-764a-414d-9c69-4d16566c93ec/MSSM_305_NeuN_pl.ploidy_2.vcf.gz.tbi
# af11efd1-0a0c-4510-b517-ae00b6c33e4c/MSSM_340_NeuN_pl.ploidy_2.vcf.gz.tbi
# b149d053-387b-4155-9c25-013ae197518b/MSSM_201_NeuN_pl.ploidy_2.vcf.gz.tbi
# b7e1a04a-cb92-4f96-a0cf-a06acb64784e/MSSM_265_NeuN_pl.ploidy_2.vcf.gz.tbi
# b858e1f1-e6d3-4fc3-9908-b227104cc6e1/MSSM_273_NeuN_pl.ploidy_2.vcf.gz.tbi
# b8b79c19-94f9-4028-9beb-85371aaac6e3/MSSM_293_NeuN_pl.ploidy_2.vcf.gz.tbi
# c1ae5ad9-12f7-4de0-a7ef-95101b37cd41/MSSM_164_NeuN_pl.ploidy_2.vcf.gz.tbi
# c1f18511-016e-4a6b-b4b4-6a18976c8edb/PITT_072_NeuN_pl.ploidy_2.vcf.gz.tbi
# c4d8c60c-f47d-425e-a9d3-2d025e79a52a/MSSM_379_NeuN_pl.ploidy_2.vcf.gz.tbi
# cb248672-f8b8-48d3-929f-d3bb1ac83206/MSSM_130_NeuN_pl.ploidy_2.vcf.gz.tbi
# cb5a4a3d-f969-4c12-bf8b-a3c25aa42357/MSSM_224_NeuN_pl.ploidy_2.vcf.gz.tbi
# ccafeeea-253d-4033-b9cc-17d741f9d4ab/MSSM_193_NeuN_pl.ploidy_2.vcf.gz.tbi
# d2336e85-c107-4e96-bf10-352758f2891a/MSSM_192_NeuN_pl.ploidy_2.vcf.gz.tbi
# d50f9924-cc1e-42fb-801b-093a3e4ddb78/MSSM_405_NeuN_pl.ploidy_2.vcf.gz.tbi
# d9c7ae8e-5916-4369-a076-d6300d3d7e32/MSSM_162_NeuN_pl.ploidy_2.vcf.gz.tbi
# df627bef-7f5d-475a-8b7c-3c0828c7e556/MSSM_161_NeuN_pl.ploidy_2.vcf.gz.tbi
# e2362fc9-8f74-4743-b496-71e7e67045db/PITT_113_NeuN_pl.ploidy_2.vcf.gz.tbi
# e25d0dcc-aadc-418f-8d3a-0b57d7d02cda/MSSM_227_NeuN_pl.ploidy_2.vcf.gz.tbi
# e4c11733-4abe-4054-9078-997bc7b75d4d/MSSM_199_NeuN_pl.ploidy_2.vcf.gz.tbi
# e7516840-5ba9-452c-9450-02c55492916e/MSSM_343_NeuN_pl.ploidy_2.vcf.gz.tbi
# e88c07c4-5f0f-4a8d-9ef1-b6bde6708e43/MSSM_033_NeuN_pl.ploidy_2.vcf.gz.tbi
# e91d7d66-89f8-464d-9ea2-209425430f8f/MSSM_269_NeuN_pl.ploidy_2.vcf.gz.tbi
# eb4f2399-a4b8-4402-a11b-a6a011d2577d/MSSM_297_NeuN_pl.ploidy_2.vcf.gz.tbi
# eccb8992-7b19-41c5-bbff-fa1abe3ff21f/MSSM_331_NeuN_pl.ploidy_2.vcf.gz.tbi
# f3314c88-332f-461b-9ad1-6b040eee4be0/MSSM_339_NeuN_pl.ploidy_2.vcf.gz.tbi
# f39741d4-0fce-44f9-bdb5-b1493db232d1/MSSM_168_NeuN_pl.ploidy_2.vcf.gz.tbi
# f3fe9ebc-b992-445d-9366-9debb165442c/MSSM_366_NeuN_pl.ploidy_2.vcf.gz.tbi
# f42cc140-1b21-4959-b884-c4c2e2959bf2/MSSM_056_NeuN_pl.ploidy_2.vcf.gz.tbi
# f55cafab-6253-451d-b13c-71a5265d6e2b/PITT_060_NeuN_pl.ploidy_2.vcf.gz.tbi
# f6c3df6c-bb6e-44f4-9dc8-26432c174dee/PITT_017_NeuN_pl.ploidy_2.vcf.gz.tbi
# f6e81cb9-6c2c-4035-9013-0886441e4c10/MSSM_099_NeuN_pl.ploidy_2.vcf.gz.tbi
# f7775e9e-648a-4431-b920-455cf2700f06/MSSM_158_NeuN_pl.ploidy_2.vcf.gz.tbi
# fb8cb53b-9016-4258-acd0-ed7df6f15922/PITT_024_NeuN_pl.ploidy_2.vcf.gz.tbi
# fba063b0-6990-4e25-90eb-705f08261ff5/MSSM_266_NeuN_pl.ploidy_2.vcf.gz.tbi
# fc3b524a-af30-40dc-874e-8a8cbb7442c3/MSSM_211_NeuN_pl.ploidy_2.vcf.gz.tbi
# Press the "Enter" key to specify directory/directories OR an s3 location by entering -s3 <bucket name> to locate your associated files:----
# ploidy_12.vcf.gz
# Running NDATools Version 0.2.3
# Opening log: /home/attila/NDAValidationResults/debug_log_20210222T210214.txt
#
# Validating files...
# Validation report output to: /home/attila/NDAValidationResults/validation_results_20210222T210214.csv
# Warnings output to: /home/attila/NDAValidationResults/validation_results_20210222T210214.csv
#
# All files have finished validating.
#
# The following files passed validation:
# UUID 22f6ed70-830c-4443-86fa-22552009082d: nichd_btb02-2021-02-02.csv
# UUID c8b95158-2dec-4803-97f0-f8c28be885dc: genomics_sample03-ploidy_12.vcf.gz.csv
# UUID d483f05d-1250-47ee-87cc-45f331893711: genomics_subject02-2021-02-02.csv
#
# Searching for associated files...
#
#  Your user does NOT have access to the following buckets. Please review the bucket and/or your AWS credentials and try again.
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
#
#  You must make sure all associated files listed in your validation file are located in the specified directory or AWS bucket. Associated file not found in specified directory:
#
# 0103f504-969c-4e90-8adb-7af980ff8844/MSSM_348_NeuN_pl.ploidy_12.vcf.gz
# 04b39aa6-45a3-4a0b-aa28-7d3b00595ef0/MSSM_222_NeuN_pl.ploidy_12.vcf.gz
# 1043567c-446e-419f-8ac6-39d9f8db8382/MSSM_340_NeuN_pl.ploidy_12.vcf.gz
# 1063d072-e5c1-477b-8dd6-383522017a4f/PITT_072_NeuN_pl.ploidy_12.vcf.gz
# 1277f599-6f6f-481b-9c9d-fe44d2baf8f7/MSSM_343_NeuN_pl.ploidy_12.vcf.gz
# 14869012-cebf-4ac4-82a6-c280f880c1f0/MSSM_199_NeuN_pl.ploidy_12.vcf.gz
# 1c011f0e-0a08-49e1-b49e-f0d6c81ee97c/MSSM_370_NeuN_pl.ploidy_12.vcf.gz
# 1f59d72a-8780-4c3a-ba73-cc122d2a17e0/MSSM_227_NeuN_pl.ploidy_12.vcf.gz
# 218b9dcd-c2f1-47c1-917c-3e95eb22c7ee/MSSM_161_NeuN_pl.ploidy_12.vcf.gz
# 24a51c2e-10f6-4ac7-95d6-af92431a46fa/MSSM_406_NeuN_pl.ploidy_12.vcf.gz
# 2530dfb8-7070-4014-9604-ae28c18e99b8/PITT_101_NeuN_pl.ploidy_12.vcf.gz
# 26ef1005-bb05-4d8b-af05-50d35466f1d5/MSSM_405_NeuN_pl.ploidy_12.vcf.gz
# 27de4fd9-005d-47a1-8e21-9890ec1c11bf/MSSM_055_NeuN_pl.ploidy_12.vcf.gz
# 2c3eabf5-f69c-4bd2-ad1b-1ee480069d64/MSSM_063_NeuN_pl.ploidy_12.vcf.gz
# 3420f208-bf7c-4b35-a3f2-adcfb7c7d657/PITT_071_NeuN_pl.ploidy_12.vcf.gz
# 34c4ecb9-d9a1-44af-9acc-615d0a5734e4/MSSM_331_NeuN_pl.ploidy_12.vcf.gz
# 3d790586-6ddc-46ff-a26a-e9c02f959213/MSSM_265_NeuN_pl.ploidy_12.vcf.gz
# 3fb0d6a0-74e1-44cb-a8ad-3f142d584843/MSSM_299_NeuN_pl.ploidy_12.vcf.gz
# 422a932b-59f1-4a73-8743-ff9f726487fb/MSSM_346_NeuN_pl.ploidy_12.vcf.gz
# 4258b0f9-b885-4aed-8ed4-914125bf51e8/MSSM_308_NeuN_pl.ploidy_12.vcf.gz
# 442e7c26-bc28-4ab3-963c-649b14755b68/PITT_052_NeuN_pl.ploidy_12.vcf.gz
# 45591d57-e3b4-4510-b4de-90c6526b543c/MSSM_033_NeuN_pl.ploidy_12.vcf.gz
# 4671b8be-2f6c-4a0a-9d9d-ffcc409002ee/PITT_050_NeuN_pl.ploidy_12.vcf.gz
# 489ba87e-1fd3-441c-b51e-999f4025f12b/MSSM_310_NeuN_pl.ploidy_12.vcf.gz
# 4cb6d68f-14f7-40fa-816d-15e97123385b/MSSM_158_NeuN_pl.ploidy_12.vcf.gz
# 538998b3-9dea-4542-a336-2ecbd3522d95/PITT_004_NeuN_pl.ploidy_12.vcf.gz
# 53928f5f-a03b-4659-9662-876b96739d11/MSSM_297_NeuN_pl.ploidy_12.vcf.gz
# 5b671fb3-76f9-407f-9e22-62c297be9905/MSSM_116_NeuN_pl.ploidy_12.vcf.gz
# 5c04d59e-7102-4a2d-898a-5e50b6bb6979/MSSM_309_NeuN_pl.ploidy_12.vcf.gz
# 5d5ee4c7-b7dd-49f3-95dd-32e28f8ff277/MSSM_213_NeuN_pl.ploidy_12.vcf.gz
# 5f4f2b16-2036-429d-8372-7f30fd2c028c/MSSM_254_NeuN_pl.ploidy_12.vcf.gz
# 63bfe660-626e-450c-be32-52da72b48800/MSSM_364_NeuN_pl.ploidy_12.vcf.gz
# 662910f1-3f12-4ce3-a65e-97668243fe3a/MSSM_287_NeuN_pl.ploidy_12.vcf.gz
# 666e4394-7120-4bcc-a441-63edd1d9c5bd/MSSM_027_NeuN_pl.ploidy_12.vcf.gz
# 674cf266-f573-4323-8291-6a4314811914/MSSM_211_NeuN_pl.ploidy_12.vcf.gz
# 6a582c7e-6915-409d-a5b8-7fc363a47f4d/MSSM_168_NeuN_pl.ploidy_12.vcf.gz
# 6ba49d0a-fa9c-40a9-92da-3777c3d6c64b/MSSM_269_NeuN_pl.ploidy_12.vcf.gz
# 7192c36d-a3a9-4070-9d0e-4c9e8c79d116/PITT_117_NeuN_pl.ploidy_12.vcf.gz
# 74b1a25f-d8b4-44f2-a2f5-8ea90b0d5a87/MSSM_339_NeuN_pl.ploidy_12.vcf.gz
# 7e9d31b6-c380-451c-9f12-3352a13fb49b/MSSM_180_NeuN_pl.ploidy_12.vcf.gz
# 80482938-75f4-4ee0-a4fa-3b0664f03cf7/MSSM_321_NeuN_pl.ploidy_12.vcf.gz
# 814043a0-4b4c-4215-8e8b-ac216b8e4fff/MSSM_293_NeuN_pl.ploidy_12.vcf.gz
# 84267d2f-3bef-43d6-84d8-31ca61685f2d/MSSM_366_NeuN_pl.ploidy_12.vcf.gz
# 849e0dc0-5d3d-40ea-beb2-f98c1a78d057/PITT_020_NeuN_pl.ploidy_12.vcf.gz
# 84f9293f-3688-4a64-9c8f-98542a064632/MSSM_363_NeuN_pl.ploidy_12.vcf.gz
# 88bac8a2-c594-48ae-b02f-d357e034c68e/MSSM_224_NeuN_pl.ploidy_12.vcf.gz
# 8a508d8f-d952-4255-a082-007d65828e32/MSSM_372_NeuN_pl.ploidy_12.vcf.gz
# 8ac45043-1ed7-42d3-b2d8-fc70a9f6fa09/MSSM_415_NeuN_pl.ploidy_12.vcf.gz
# 90feaeb4-6921-4748-a3c9-7a37939e1619/PITT_113_NeuN_pl.ploidy_12.vcf.gz
# 919c7ddf-7cf6-4308-bd8d-158be31d2492/MSSM_065_NeuN_pl.ploidy_12.vcf.gz
# 9978d1ec-6eb3-4601-8144-1dc6bee640c0/PITT_024_NeuN_pl.ploidy_12.vcf.gz
# a4b4bf22-1e47-45df-b699-e7a8316d2dc2/MSSM_192_NeuN_pl.ploidy_12.vcf.gz
# a82740b2-1852-4f09-996c-dc23ffd10af5/PITT_036_NeuN_pl.ploidy_12.vcf.gz
# ab9b463a-ec7f-4ad4-a9a1-973f4e74133c/PITT_060_NeuN_pl.ploidy_12.vcf.gz
# accb1047-cde1-45f0-a032-06f2a15f344a/MSSM_291_NeuN_pl.ploidy_12.vcf.gz
# adc2e704-afc4-4d2d-b0bc-a73af1823dbe/MSSM_097_NeuN_pl.ploidy_12.vcf.gz
# af4525ed-e536-4bcb-bbb3-d65eb83708ee/MSSM_130_NeuN_pl.ploidy_12.vcf.gz
# b048c1fd-40f2-49f5-9932-4ed338f0c086/MSSM_201_NeuN_pl.ploidy_12.vcf.gz
# b2c267fe-2524-4fb6-8b8f-938b35ece980/MSSM_056_NeuN_pl.ploidy_12.vcf.gz
# b3a4cc78-cebb-4fe7-b34f-433fd974f6d3/MSSM_295_NeuN_pl.ploidy_12.vcf.gz
# b5d186e5-2b20-47ea-91ab-943a2b7e4b68/MSSM_099_NeuN_pl.ploidy_12.vcf.gz
# b838e3ff-33b3-4a49-bd32-fdccea6453ae/PITT_082_NeuN_pl.ploidy_12.vcf.gz
# bb5ee6f1-978e-4641-9902-3f2fd4735cbd/PITT_098_NeuN_pl.ploidy_12.vcf.gz
# c06b2273-4134-4c55-84d5-31828a2a3f14/MSSM_305_NeuN_pl.ploidy_12.vcf.gz
# c11cadc7-4588-49e6-8a01-4ddd2991697f/MSSM_273_NeuN_pl.ploidy_12.vcf.gz
# c20973c3-3194-4f82-8e3f-7fe41a9b9489/MSSM_352_NeuN_pl.ploidy_12.vcf.gz
# c52ea166-2cc7-4cd9-82fd-b6818f27dd04/MSSM_304_NeuN_pl.ploidy_12.vcf.gz
# cbae23a4-3f9b-43b6-9c02-4f9522f85654/MSSM_142_NeuN_pl.ploidy_12.vcf.gz
# cf3c0b6e-c26c-45dd-98d5-b21ba185bbfd/MSSM_362_NeuN_pl.ploidy_12.vcf.gz
# daaeb055-e7ec-4be5-9cfc-f3f98f3ca179/MSSM_100_NeuN_pl.ploidy_12.vcf.gz
# dad4f051-cf92-4558-be86-9ad30a93f5d5/MSSM_379_NeuN_pl.ploidy_12.vcf.gz
# e244e582-ee65-4ab6-977f-5a7e2e992fe1/MSSM_193_NeuN_pl.ploidy_12.vcf.gz
# e2fbbba6-657f-4443-a958-4aa99bac49c4/MSSM_327_NeuN_pl.ploidy_12.vcf.gz
# e4e6d227-2156-4052-a234-678d2fa06a1b/MSSM_178_NeuN_pl.ploidy_12.vcf.gz
# ec5aee6b-614e-4e88-88e8-a916a6135f96/MSSM_164_NeuN_pl.ploidy_12.vcf.gz
# eeaa54d7-e8e7-4cbb-acde-67a6d18b97ab/MSSM_266_NeuN_pl.ploidy_12.vcf.gz
# f3531831-9dcb-4e70-97a3-2deab7173d5b/MSSM_069_NeuN_pl.ploidy_12.vcf.gz
# f49d71f7-4c04-4261-9d6a-3ea2e558718a/PITT_007_NeuN_pl.ploidy_12.vcf.gz
# f6b98508-cd15-46f4-a611-7f8716cd9ef8/PITT_017_NeuN_pl.ploidy_12.vcf.gz
# fc06c1f5-a8f3-43d4-b871-62bb38d71bc4/MSSM_162_NeuN_pl.ploidy_12.vcf.gz
# ffa431fd-280f-4cae-af36-2e8f8d89b046/MSSM_338_NeuN_pl.ploidy_12.vcf.gz
# Press the "Enter" key to specify directory/directories OR an s3 location by entering -s3 <bucket name> to locate your associated files:----
# ploidy_12.vcf.gz.tbi
# Running NDATools Version 0.2.3
# Opening log: /home/attila/NDAValidationResults/debug_log_20210222T210218.txt
#
# Validating files...
# ...
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
# nda-bsmn-scratch
#
#  You must make sure all associated files listed in your validation file are located in the specified directory or AWS bucket. Associated file not found in specified directory:
#
# 006108c2-87c5-4e42-9f49-32b956f7c3c5/MSSM_254_NeuN_pl.unmapped.bam
# 0312f422-333a-4cb5-a96b-571303f9e75b/PITT_004_NeuN_pl.unmapped.bam
# 03926587-0de1-40fa-894e-ce35e457c7d2/MSSM_168_NeuN_pl.unmapped.bam
# 05c31851-175d-4c52-a6d1-422f4cc53692/MSSM_180_NeuN_pl.unmapped.bam
# 07a38dc2-0943-42f4-8142-b8355faf442d/MSSM_161_NeuN_pl.unmapped.bam
# 14006840-4b61-499d-adea-e881b9e3dc85/PITT_050_NeuN_pl.unmapped.bam
# 155f55fe-8251-4223-bd5a-b79a32d2debe/MSSM_405_NeuN_pl.unmapped.bam
# 165dc228-7451-4fed-ac82-fbd93eda58f7/MSSM_291_NeuN_pl.unmapped.bam
# 16a11189-e501-4d6d-8e8d-ef141478dba8/MSSM_321_NeuN_pl.unmapped.bam
# 17867fae-d6b0-4289-92a6-14276ed37b04/MSSM_097_NeuN_pl.unmapped.bam
# 18cf9f86-3e03-43cb-906f-0200f63886de/MSSM_269_NeuN_pl.unmapped.bam
# 1ea6e46b-7be0-4f4e-b7a0-c83974901654/PITT_052_NeuN_pl.unmapped.bam
# 295ba82f-8f14-4e50-8945-4496f5131c9e/MSSM_027_NeuN_pl.unmapped.bam
# 2b2a59bc-0109-43c1-adaf-6b330c6f1eeb/MSSM_343_NeuN_pl.unmapped.bam
# 2b8d3b25-3654-43e8-b188-a4089b1afd93/PITT_101_NeuN_pl.unmapped.bam
# 308f6cae-97ff-4dc4-a7b5-d45e3e93a40e/MSSM_069_NeuN_pl.unmapped.bam
# 30e87dca-79ce-4a45-b515-9f920b232eb7/MSSM_099_NeuN_pl.unmapped.bam
# 32600187-842a-4d2d-b6b3-8cacbe2bea1e/MSSM_211_NeuN_pl.unmapped.bam
# 33b45613-6fd5-4e6f-84db-161ff0f946fb/MSSM_406_NeuN_pl.unmapped.bam
# 35a00e62-f0ff-4168-9070-fd10c9626208/MSSM_213_NeuN_pl.unmapped.bam
# 37f30534-24f9-4043-b625-0f87fbb8928f/MSSM_293_NeuN_pl.unmapped.bam
# 3ba8181f-61f4-487f-a54d-8739327234b6/MSSM_379_NeuN_pl.unmapped.bam
# 3c5c4bb5-646e-4acf-a056-b0ef05b25182/MSSM_065_NeuN_pl.unmapped.bam
# 3d26b440-1ca6-4f25-86de-f75a18f806f8/MSSM_164_NeuN_pl.unmapped.bam
# 46d162c5-ecd1-4b9d-9e79-6a25970a91bb/MSSM_327_NeuN_pl.unmapped.bam
# 4dafc70f-8cb0-4b29-86c9-ad55af5b8270/PITT_060_NeuN_pl.unmapped.bam
# 4ddde094-213d-4c96-a260-4397d4d54dcc/PITT_071_NeuN_pl.unmapped.bam
# 5002b982-214e-4749-89af-21557e9dae37/MSSM_192_NeuN_pl.unmapped.bam
# 51a9e208-6645-454e-8f69-682636738147/MSSM_222_NeuN_pl.unmapped.bam
# 5404864b-797c-4c47-a2e6-5bc5da82bc7c/MSSM_295_NeuN_pl.unmapped.bam
# 611eeba9-5e0c-4188-b60a-3c127da56a67/MSSM_310_NeuN_pl.unmapped.bam
# 6af2d377-03d9-42ec-bb56-8d8844054fd6/MSSM_372_NeuN_pl.unmapped.bam
# 6bc363b9-c206-4874-a1ea-4a083262f790/MSSM_348_NeuN_pl.unmapped.bam
# 6f781e85-6701-457e-b95e-8b9be39a347a/MSSM_100_NeuN_pl.unmapped.bam
# 71432785-c25a-407f-a3ac-f096d7dafbd7/MSSM_130_NeuN_pl.unmapped.bam
# 73ad99fb-6938-4c2f-9649-f2e148566218/MSSM_266_NeuN_pl.unmapped.bam
# 741d0d3f-abd5-47b8-a989-fe6c3f00d55e/MSSM_055_NeuN_pl.unmapped.bam
# 749c6463-74d7-416e-bfff-800038b07c2e/MSSM_227_NeuN_pl.unmapped.bam
# 7811ae78-8446-4b4b-9750-9ce478208a11/MSSM_162_NeuN_pl.unmapped.bam
# 7ac4906a-71cd-4c8e-9e3c-6e1f2c96de5e/MSSM_265_NeuN_pl.unmapped.bam
# 80c1d716-a48e-444b-981d-94dc00b0fc49/MSSM_363_NeuN_pl.unmapped.bam
# 86d5703c-4c33-43fe-91b6-4283bb07ef71/MSSM_201_NeuN_pl.unmapped.bam
# 88699af1-a541-4526-b351-8f5984d6df17/MSSM_033_NeuN_pl.unmapped.bam
# 8dc9dc6f-61df-4d90-a36b-f4a32bdff594/PITT_113_NeuN_pl.unmapped.bam
# 90316288-8e56-43b5-90a8-90f268004fa0/MSSM_362_NeuN_pl.unmapped.bam
# 914a219a-149a-4922-a596-a1d3dcf995d7/MSSM_224_NeuN_pl.unmapped.bam
# 92328bcb-13fc-4f0a-89d4-8261078c68dc/PITT_024_NeuN_pl.unmapped.bam
# 9750f337-a1f3-4a42-958b-a2fbae907d2d/MSSM_352_NeuN_pl.unmapped.bam
# 9d654886-4686-45d8-b4d3-76343d325e88/MSSM_309_NeuN_pl.unmapped.bam
# 9dd0be8a-98bc-4d33-a2bf-b6e7fe59fed7/MSSM_308_NeuN_pl.unmapped.bam
# a3cafdfc-30b2-4a7c-9a89-b76296e28f11/MSSM_331_NeuN_pl.unmapped.bam
# a4290bfd-6063-462c-a54c-a7e37f600ad4/MSSM_063_NeuN_pl.unmapped.bam
# a539b415-0cce-460d-834b-9abf956214fa/MSSM_178_NeuN_pl.unmapped.bam
# a5bca118-a267-402a-977c-7257e5f26f5a/MSSM_297_NeuN_pl.unmapped.bam
# a877be33-4ca7-4165-b2a3-178bbd818d0f/PITT_082_NeuN_pl.unmapped.bam
# aa5ee11b-05e8-4b18-a861-5f7f8a4065d5/MSSM_142_NeuN_pl.unmapped.bam
# ab30f257-8a8e-4b11-a442-28a5e0326d91/MSSM_346_NeuN_pl.unmapped.bam
# abbcfd1c-e2f8-4cdd-8bb3-8b26c0a26788/PITT_098_NeuN_pl.unmapped.bam
# b78312ee-cd6f-4eae-a189-bd64c776c71b/MSSM_364_NeuN_pl.unmapped.bam
# bc52db52-ba9d-49e4-a9fb-5bc2ec7e22e3/PITT_072_NeuN_pl.unmapped.bam
# c578744e-f1ed-45cd-a43b-a0a28a870c3b/PITT_007_NeuN_pl.unmapped.bam
# c5cc1b44-a137-4593-8625-f6c8be6f99d6/MSSM_056_NeuN_pl.unmapped.bam
# c60017a9-856b-48eb-b6a1-ae2e7b5e22ee/MSSM_273_NeuN_pl.unmapped.bam
# cdee6637-ced7-4300-a9be-e68ce2a0b1f3/MSSM_338_NeuN_pl.unmapped.bam
# ce929aaf-68b5-4293-b0a0-1907d7a0ab5a/MSSM_370_NeuN_pl.unmapped.bam
# d03c53ea-0f0d-4d37-8a3e-3b46722c7936/MSSM_340_NeuN_pl.unmapped.bam
# d22acb90-4767-4a08-81e6-8a9413053388/MSSM_116_NeuN_pl.unmapped.bam
# d5ab578d-b6f4-4cf1-8115-0809b95cbab8/PITT_017_NeuN_pl.unmapped.bam
# d5cf75dc-23b4-4ecc-ad22-82d46864ef6e/PITT_020_NeuN_pl.unmapped.bam
# d9295310-be70-4fd8-8a0b-f07d0de08e7f/MSSM_299_NeuN_pl.unmapped.bam
# e0e7c623-f26f-4d5f-8705-c2334a2508d3/PITT_036_NeuN_pl.unmapped.bam
# eaf3b9b6-47be-4f3b-80b7-a951610b5877/MSSM_305_NeuN_pl.unmapped.bam
# f0016dbd-6eac-4ac9-a49e-d6ea78cf22c1/MSSM_287_NeuN_pl.unmapped.bam
# f046078f-fd9c-4340-bd79-7f6c8bf32297/MSSM_199_NeuN_pl.unmapped.bam
# f1571107-adea-40bf-a738-becf20d9874e/MSSM_193_NeuN_pl.unmapped.bam
# f6640c2d-b348-4ef0-8f46-879a85cb3a84/MSSM_415_NeuN_pl.unmapped.bam
# f74136fd-9dba-4139-870d-02572d8aa770/MSSM_366_NeuN_pl.unmapped.bam
# f765f1c7-f819-4af0-a760-7fcf79d129aa/MSSM_339_NeuN_pl.unmapped.bam
# f8bdbd55-f1f2-452c-bd5f-9eea47accbd9/MSSM_304_NeuN_pl.unmapped.bam
# ff701e05-93c9-487c-bb2a-f88c1617d880/MSSM_158_NeuN_pl.unmapped.bam
# Press the "Enter" key to specify directory/directories OR an s3 location by entering -s3 <bucket name> to locate your associated files:----
# 100%|██████████| 3/3 [00:01<00:00,  1.66it/s]
# Traceback (most recent call last):
#   File "/home/attila/.local/bin/vtcmd", line 8, in <module>
#     sys.exit(main())
#   File "/home/attila/.local/lib/python3.7/site-packages/NDATools/clientscripts/vtcmd.py", line 290, in main
#     package_results = build_package(uuid, associated_files, config=config)
#   File "/home/attila/.local/lib/python3.7/site-packages/NDATools/clientscripts/vtcmd.py", line 237, in build_package
#     package.file_search(directories, source_bucket, source_prefix, retry_allowed=True)
#   File "/home/attila/.local/lib/python3.7/site-packages/NDATools/BuildPackage.py", line 226, in file_search
#     self.recollect_file_search_info()
#   File "/home/attila/.local/lib/python3.7/site-packages/NDATools/BuildPackage.py", line 150, in recollect_file_search_info
#     retry = input('Press the "Enter" key to specify directory/directories OR an s3 location by entering -s3 '
# EOFError: EOF when reading a line
# 100%|██████████| 3/3 [00:01<00:00,  2.30it/s]
# Traceback (most recent call last):
#   File "/home/attila/.local/bin/vtcmd", line 8, in <module>
#     sys.exit(main())
#   File "/home/attila/.local/lib/python3.7/site-packages/NDATools/clientscripts/vtcmd.py", line 290, in main
#     package_results = build_package(uuid, associated_files, config=config)
#   File "/home/attila/.local/lib/python3.7/site-packages/NDATools/clientscripts/vtcmd.py", line 237, in build_package
#     package.file_search(directories, source_bucket, source_prefix, retry_allowed=True)
#   File "/home/attila/.local/lib/python3.7/site-packages/NDATools/BuildPackage.py", line 226, in file_search
#     self.recollect_file_search_info()
#   File "/home/attila/.local/lib/python3.7/site-packages/NDATools/BuildPackage.py", line 150, in recollect_file_search_info
#     retry = input('Press the "Enter" key to specify directory/directories OR an s3 location by entering -s3 '
# EOFError: EOF when reading a line
# 100%|██████████| 3/3 [00:01<00:00,  2.71it/s]
# Traceback (most recent call last):
#   File "/home/attila/.local/bin/vtcmd", line 8, in <module>
#     sys.exit(main())
#   File "/home/attila/.local/lib/python3.7/site-packages/NDATools/clientscripts/vtcmd.py", line 290, in main
#     package_results = build_package(uuid, associated_files, config=config)
#   File "/home/attila/.local/lib/python3.7/site-packages/NDATools/clientscripts/vtcmd.py", line 237, in build_package
#     package.file_search(directories, source_bucket, source_prefix, retry_allowed=True)
#   File "/home/attila/.local/lib/python3.7/site-packages/NDATools/BuildPackage.py", line 226, in file_search
#     self.recollect_file_search_info()
#   File "/home/attila/.local/lib/python3.7/site-packages/NDATools/BuildPackage.py", line 150, in recollect_file_search_info
#     retry = input('Press the "Enter" key to specify directory/directories OR an s3 location by entering -s3 '
# EOFError: EOF when reading a line
# 100%|██████████| 3/3 [00:02<00:00,  1.42it/s]
# Traceback (most recent call last):
#   File "/home/attila/.local/bin/vtcmd", line 8, in <module>
#     sys.exit(main())
#   File "/home/attila/.local/lib/python3.7/site-packages/NDATools/clientscripts/vtcmd.py", line 290, in main
#     package_results = build_package(uuid, associated_files, config=config)
#   File "/home/attila/.local/lib/python3.7/site-packages/NDATools/clientscripts/vtcmd.py", line 237, in build_package
#     package.file_search(directories, source_bucket, source_prefix, retry_allowed=True)
#   File "/home/attila/.local/lib/python3.7/site-packages/NDATools/BuildPackage.py", line 226, in file_search
#     self.recollect_file_search_info()
#   File "/home/attila/.local/lib/python3.7/site-packages/NDATools/BuildPackage.py", line 150, in recollect_file_search_info
#     retry = input('Press the "Enter" key to specify directory/directories OR an s3 location by entering -s3 '
# EOFError: EOF when reading a line
# 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# Traceback (most recent call last):
#   File "/home/attila/.local/bin/vtcmd", line 8, in <module>
#     sys.exit(main())
#   File "/home/attila/.local/lib/python3.7/site-packages/NDATools/clientscripts/vtcmd.py", line 290, in main
#     package_results = build_package(uuid, associated_files, config=config)
#   File "/home/attila/.local/lib/python3.7/site-packages/NDATools/clientscripts/vtcmd.py", line 237, in build_package
#     package.file_search(directories, source_bucket, source_prefix, retry_allowed=True)
#   File "/home/attila/.local/lib/python3.7/site-packages/NDATools/BuildPackage.py", line 226, in file_search
#     self.recollect_file_search_info()
#   File "/home/attila/.local/lib/python3.7/site-packages/NDATools/BuildPackage.py", line 150, in recollect_file_search_info
#     retry = input('Press the "Enter" key to specify directory/directories OR an s3 location by entering -s3 '
# EOFError: EOF when reading a line
# 100%|██████████| 3/3 [00:01<00:00,  2.13it/s]
# Traceback (most recent call last):
#   File "/home/attila/.local/bin/vtcmd", line 8, in <module>
#     sys.exit(main())
#   File "/home/attila/.local/lib/python3.7/site-packages/NDATools/clientscripts/vtcmd.py", line 290, in main
#     package_results = build_package(uuid, associated_files, config=config)
#   File "/home/attila/.local/lib/python3.7/site-packages/NDATools/clientscripts/vtcmd.py", line 237, in build_package
#     package.file_search(directories, source_bucket, source_prefix, retry_allowed=True)
#   File "/home/attila/.local/lib/python3.7/site-packages/NDATools/BuildPackage.py", line 226, in file_search
#     self.recollect_file_search_info()
#   File "/home/attila/.local/lib/python3.7/site-packages/NDATools/BuildPackage.py", line 150, in recollect_file_search_info
#     retry = input('Press the "Enter" key to specify directory/directories OR an s3 location by entering -s3 '
# EOFError: EOF when reading a line
# 100%|██████████| 3/3 [00:01<00:00,  2.71it/s]
# Traceback (most recent call last):
#   File "/home/attila/.local/bin/vtcmd", line 8, in <module>
#     sys.exit(main())
#   File "/home/attila/.local/lib/python3.7/site-packages/NDATools/clientscripts/vtcmd.py", line 290, in main
#     package_results = build_package(uuid, associated_files, config=config)
#   File "/home/attila/.local/lib/python3.7/site-packages/NDATools/clientscripts/vtcmd.py", line 237, in build_package
#     package.file_search(directories, source_bucket, source_prefix, retry_allowed=True)
#   File "/home/attila/.local/lib/python3.7/site-packages/NDATools/BuildPackage.py", line 226, in file_search
#     self.recollect_file_search_info()
#   File "/home/attila/.local/lib/python3.7/site-packages/NDATools/BuildPackage.py", line 150, in recollect_file_search_info
#     retry = input('Press the "Enter" key to specify directory/directories OR an s3 location by entering -s3 '
# EOFError: EOF when reading a line
# 100%|██████████| 3/3 [00:01<00:00,  1.99it/s]
# Traceback (most recent call last):
#   File "/home/attila/.local/bin/vtcmd", line 8, in <module>
#     sys.exit(main())
#   File "/home/attila/.local/lib/python3.7/site-packages/NDATools/clientscripts/vtcmd.py", line 290, in main
#     package_results = build_package(uuid, associated_files, config=config)
#   File "/home/attila/.local/lib/python3.7/site-packages/NDATools/clientscripts/vtcmd.py", line 237, in build_package
#     package.file_search(directories, source_bucket, source_prefix, retry_allowed=True)
#   File "/home/attila/.local/lib/python3.7/site-packages/NDATools/BuildPackage.py", line 226, in file_search
#     self.recollect_file_search_info()
#   File "/home/attila/.local/lib/python3.7/site-packages/NDATools/BuildPackage.py", line 150, in recollect_file_search_info
#     retry = input('Press the "Enter" key to specify directory/directories OR an s3 location by entering -s3 '
# EOFError: EOF when reading a line
# 100%|██████████| 3/3 [00:01<00:00,  2.71it/s]
# Traceback (most recent call last):
#   File "/home/attila/.local/bin/vtcmd", line 8, in <module>
#     sys.exit(main())
#   File "/home/attila/.local/lib/python3.7/site-packages/NDATools/clientscripts/vtcmd.py", line 290, in main
#     package_results = build_package(uuid, associated_files, config=config)
#   File "/home/attila/.local/lib/python3.7/site-packages/NDATools/clientscripts/vtcmd.py", line 237, in build_package
#     package.file_search(directories, source_bucket, source_prefix, retry_allowed=True)
#   File "/home/attila/.local/lib/python3.7/site-packages/NDATools/BuildPackage.py", line 226, in file_search
#     self.recollect_file_search_info()
#   File "/home/attila/.local/lib/python3.7/site-packages/NDATools/BuildPackage.py", line 150, in recollect_file_search_info
#     retry = input('Press the "Enter" key to specify directory/directories OR an s3 location by entering -s3 '
# EOFError: EOF when reading a line
# 100%|██████████| 3/3 [00:01<00:00,  2.71it/s]
# Traceback (most recent call last):
#   File "/home/attila/.local/bin/vtcmd", line 8, in <module>
#     sys.exit(main())
#   File "/home/attila/.local/lib/python3.7/site-packages/NDATools/clientscripts/vtcmd.py", line 290, in main
#     package_results = build_package(uuid, associated_files, config=config)
#   File "/home/attila/.local/lib/python3.7/site-packages/NDATools/clientscripts/vtcmd.py", line 237, in build_package
#     package.file_search(directories, source_bucket, source_prefix, retry_allowed=True)
#   File "/home/attila/.local/lib/python3.7/site-packages/NDATools/BuildPackage.py", line 226, in file_search
#     self.recollect_file_search_info()
#   File "/home/attila/.local/lib/python3.7/site-packages/NDATools/BuildPackage.py", line 150, in recollect_file_search_info
#     retry = input('Press the "Enter" key to specify directory/directories OR an s3 location by entering -s3 '
# EOFError: EOF when reading a line

# %%
# %connect_info
# Out:
# {
#   "shell_port": 59245,
#   "iopub_port": 41551,
#   "stdin_port": 34749,
#   "control_port": 57099,
#   "hb_port": 57723,
#   "ip": "127.0.0.1",
#   "key": "7fcd38c5-b742590ef2dcdd4f126234c4",
#   "transport": "tcp",
#   "signature_scheme": "hmac-sha256",
#   "kernel_name": ""
# }
#
# Paste the above JSON into a file, and connect with:
#     $> jupyter <app> --existing <file>
# or, if you are local, you can connect with just:
#     $> jupyter <app> --existing kernel-cfd88a2b-1421-422b-b9c9-ef68b2bf3f90.json
# or even just:
#     $> jupyter <app> --existing
# if this is the most recent Jupyter kernel you have started.
