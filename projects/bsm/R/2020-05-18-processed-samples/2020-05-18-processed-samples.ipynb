# %% [markdown]
# The status of samples on Ada, BSMN scratch space and GENEWIZ project 30-317737003 denoted here as g003.

# %% [markdown]
# ## Preparation

# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import synapseclient
import synapseutils
import re
import os.path
syn = synapseclient.login()
# Out:
# Welcome, Attila Jones!

# %%
wdir = '/home/attila/projects/bsm/results/2020-05-18-processed-samples/'
# CMC_Human_clinical_metadata.csv
cmc_clinical_syn = syn.get('syn2279441', downloadLocation=wdir, ifcollision='overwrite.local')
cmc_clinical = pd.read_csv(cmc_clinical_syn.path, index_col='Individual ID')

# %% [markdown]
# Sequenced samples from Ada

# %%
ada_path = '/home/attila/projects/bsm/results/2018-09-12-sequenced-individuals/sequenced-samples.csv'
ada = pd.read_csv(ada_path)
# index with sample IDs like MSSM_033_NeuN_pl
ada.index = [y[0].replace('CMC_', '') + '_' + y[1] for y in zip(ada['Individual ID'], ada['Tissue'])]

# %% [markdown]
# Processed samples from *Scratch Space »  BSMN_grant_data »  WGS.SCZ.Chess » alignment* Synapse folder [syn20735395](https://www.synapse.org/#!Synapse:syn20735395)

# %%
scratch = list(synapseutils.walk(syn, 'syn20735395'))[0][2] # get file list
scratch = [y for y in scratch if re.match('^.*\.cram$', y[0])] # retain only .cram files and remove everything else like .crai files
entities = [syn.get(y[1], downloadFile=False) for y in scratch]

# %%
def entity2df(e, cmc_clinical=cmc_clinical):
    '''given Synapse entity e create one-lined data frame'''
    simple_id = re.sub('_(muscle|NeuN_pl|NeuN_mn).*$', '', e.name)
    indiv_id = 'CMC_' + simple_id
    d = dict()
    d['Individual ID'] = indiv_id
    d['Dx'] = cmc_clinical.loc[indiv_id, 'Dx']
    d['Tissue'] = re.sub('^.*(muscle|NeuN_pl|NeuN_mn).*$', '\\1', e.name)
    d['File name'] = e.name
    d['Modification time'] = e.modifiedOn
    users = {'3388274': '@cmolitor', '3340241': '@taejeong', '3338602': '@attilajones'}
    d['Created by'] = users[e.createdBy]
    d['Modified by'] = users[e.modifiedBy]
    d['Size GiB'] = e._file_handle.contentSize / 2 ** 30
    e._file_handle.contentSize
    df = pd.DataFrame(d, index=[e.name.replace('.cram', '')])
    return(df)

scratch = pd.concat([entity2df(e) for e in entities])
scratch.head()
# Out:
#                  Individual ID       Dx   Tissue              File name  \
# MSSM_027_NeuN_pl  CMC_MSSM_027      SCZ  NeuN_pl  MSSM_027_NeuN_pl.cram
# MSSM_056_muscle   CMC_MSSM_056  Control   muscle   MSSM_056_muscle.cram
# MSSM_106_NeuN_mn  CMC_MSSM_106  Control  NeuN_mn  MSSM_106_NeuN_mn.cram
# MSSM_106_NeuN_pl  CMC_MSSM_106  Control  NeuN_pl  MSSM_106_NeuN_pl.cram
# MSSM_106_muscle   CMC_MSSM_106  Control   muscle   MSSM_106_muscle.cram
#
#                          Modification time    Created by   Modified by  \
# MSSM_027_NeuN_pl  2020-05-02T15:56:53.425Z  @attilajones  @attilajones
# MSSM_056_muscle   2020-03-13T20:18:16.206Z     @taejeong     @cmolitor
# MSSM_106_NeuN_mn  2020-03-13T20:18:16.812Z     @taejeong     @cmolitor
# MSSM_106_NeuN_pl  2020-03-13T20:20:05.209Z     @taejeong     @cmolitor
# MSSM_106_muscle   2020-03-13T20:19:32.261Z     @taejeong     @cmolitor
#
#                     Size GiB
# MSSM_027_NeuN_pl   59.431365
# MSSM_056_muscle    52.598372
# MSSM_106_NeuN_mn   55.699787
# MSSM_106_NeuN_pl  226.807344
# MSSM_106_muscle    61.918579

# %%
samples_ada = set(ada.index)
samples_scratch = set(scratch.index)

# %% [markdown]
# Samples in Chaggai's table for GENEWIZ project 30-317737003.

# %%
g003 = pd.read_csv('/home/attila/projects/bsm/tables/samples-from-Chaggai.csv')
g003.index = [y + '_NeuN_pl' for y in g003['CMC_simple_id']]
g003['Individual ID'] = ['CMC_' + y for y in g003['CMC_simple_id']]
g003['Tissue'] = 'NeuN_pl'
# correction: from CONTROL to Control
g003['Dx'] = [re.sub('ONTROL', 'ontrol', y) for y in g003['Dx']]
g003.head()
# Out:
#                  CMC_simple_id Dissection PFC #   Dx GENEWIZ_serialn Index  \
# PITT_117_NeuN_pl      PITT_117       PITT   904  SCZ               1    A2
# MSSM_364_NeuN_pl      MSSM_364       MSSM  1141  SCZ               2    A3
# MSSM_363_NeuN_pl      MSSM_363       MSSM  1144  SCZ               3    A4
# MSSM_308_NeuN_pl      MSSM_308       MSSM  1153  SCZ               5    A5
# MSSM_339_NeuN_pl      MSSM_339       MSSM  1155  SCZ               6    A6
#
#                  Individual ID   Tissue
# PITT_117_NeuN_pl  CMC_PITT_117  NeuN_pl
# MSSM_364_NeuN_pl  CMC_MSSM_364  NeuN_pl
# MSSM_363_NeuN_pl  CMC_MSSM_363  NeuN_pl
# MSSM_308_NeuN_pl  CMC_MSSM_308  NeuN_pl
# MSSM_339_NeuN_pl  CMC_MSSM_339  NeuN_pl

# %% [markdown]
# ## Results
# ### Processed samples from Ada
# Samples on Ada that have been processed by bsmn-pipeline.  Note that it was Taejeong who did the work.

# %%
scratch.loc[samples_ada.intersection(samples_scratch), :]
# Out:
#                  Individual ID       Dx   Tissue              File name  \
# PITT_118_NeuN_mn  CMC_PITT_118      SCZ  NeuN_mn  PITT_118_NeuN_mn.cram
# MSSM_183_muscle   CMC_MSSM_183  Control   muscle   MSSM_183_muscle.cram
# MSSM_183_NeuN_mn  CMC_MSSM_183  Control  NeuN_mn  MSSM_183_NeuN_mn.cram
# MSSM_295_muscle   CMC_MSSM_295      SCZ   muscle   MSSM_295_muscle.cram
# MSSM_118_muscle   CMC_MSSM_118      SCZ   muscle   MSSM_118_muscle.cram
# MSSM_106_NeuN_pl  CMC_MSSM_106  Control  NeuN_pl  MSSM_106_NeuN_pl.cram
# MSSM_373_NeuN_pl  CMC_MSSM_373      SCZ  NeuN_pl  MSSM_373_NeuN_pl.cram
# MSSM_175_NeuN_pl  CMC_MSSM_175  Control  NeuN_pl  MSSM_175_NeuN_pl.cram
# MSSM_118_NeuN_pl  CMC_MSSM_118      SCZ  NeuN_pl  MSSM_118_NeuN_pl.cram
# PITT_091_NeuN_pl  CMC_PITT_091      SCZ  NeuN_pl  PITT_091_NeuN_pl.cram
# MSSM_304_muscle   CMC_MSSM_304      SCZ   muscle   MSSM_304_muscle.cram
# MSSM_369_muscle   CMC_MSSM_369  Control   muscle   MSSM_369_muscle.cram
# MSSM_109_NeuN_pl  CMC_MSSM_109  Control  NeuN_pl  MSSM_109_NeuN_pl.cram
# MSSM_391_NeuN_mn  CMC_MSSM_391  Control  NeuN_mn  MSSM_391_NeuN_mn.cram
# MSSM_056_muscle   CMC_MSSM_056  Control   muscle   MSSM_056_muscle.cram
# MSSM_369_NeuN_mn  CMC_MSSM_369  Control  NeuN_mn  MSSM_369_NeuN_mn.cram
# PITT_064_NeuN_mn  CMC_PITT_064  Control  NeuN_mn  PITT_064_NeuN_mn.cram
# PITT_064_NeuN_pl  CMC_PITT_064  Control  NeuN_pl  PITT_064_NeuN_pl.cram
# MSSM_369_NeuN_pl  CMC_MSSM_369  Control  NeuN_pl  MSSM_369_NeuN_pl.cram
# MSSM_106_NeuN_mn  CMC_MSSM_106  Control  NeuN_mn  MSSM_106_NeuN_mn.cram
# PITT_010_NeuN_pl  CMC_PITT_010  Control  NeuN_pl  PITT_010_NeuN_pl.cram
# PITT_010_NeuN_mn  CMC_PITT_010  Control  NeuN_mn  PITT_010_NeuN_mn.cram
# MSSM_109_NeuN_mn  CMC_MSSM_109  Control  NeuN_mn  MSSM_109_NeuN_mn.cram
# MSSM_215_NeuN_pl  CMC_MSSM_215  Control  NeuN_pl  MSSM_215_NeuN_pl.cram
# MSSM_179_muscle   CMC_MSSM_179  Control   muscle   MSSM_179_muscle.cram
# MSSM_179_NeuN_pl  CMC_MSSM_179  Control  NeuN_pl  MSSM_179_NeuN_pl.cram
# MSSM_391_muscle   CMC_MSSM_391  Control   muscle   MSSM_391_muscle.cram
# MSSM_183_NeuN_pl  CMC_MSSM_183  Control  NeuN_pl  MSSM_183_NeuN_pl.cram
# MSSM_179_NeuN_mn  CMC_MSSM_179  Control  NeuN_mn  MSSM_179_NeuN_mn.cram
# MSSM_106_muscle   CMC_MSSM_106  Control   muscle   MSSM_106_muscle.cram
# MSSM_331_muscle   CMC_MSSM_331      SCZ   muscle   MSSM_331_muscle.cram
# PITT_118_NeuN_pl  CMC_PITT_118      SCZ  NeuN_pl  PITT_118_NeuN_pl.cram
# MSSM_391_NeuN_pl  CMC_MSSM_391  Control  NeuN_pl  MSSM_391_NeuN_pl.cram
# MSSM_109_muscle   CMC_MSSM_109  Control   muscle   MSSM_109_muscle.cram
# PITT_091_NeuN_mn  CMC_PITT_091      SCZ  NeuN_mn  PITT_091_NeuN_mn.cram
#
#                          Modification time Created by Modified by    Size GiB
# PITT_118_NeuN_mn  2020-03-13T20:18:17.841Z  @taejeong   @cmolitor   52.733003
# MSSM_183_muscle   2020-03-13T20:18:17.380Z  @taejeong   @cmolitor   47.477500
# MSSM_183_NeuN_mn  2020-03-13T20:18:19.052Z  @taejeong   @cmolitor   62.790291
# MSSM_295_muscle   2020-03-13T20:18:19.455Z  @taejeong   @cmolitor   56.074964
# MSSM_118_muscle   2020-03-13T20:18:16.688Z  @taejeong   @cmolitor   48.005579
# MSSM_106_NeuN_pl  2020-03-13T20:20:05.209Z  @taejeong   @cmolitor  226.807344
# MSSM_373_NeuN_pl  2020-03-13T20:20:17.553Z  @taejeong   @cmolitor  304.313954
# MSSM_175_NeuN_pl  2020-03-13T20:19:55.225Z  @taejeong   @cmolitor  176.807351
# MSSM_118_NeuN_pl  2020-03-13T20:18:19.573Z  @taejeong   @cmolitor   99.492850
# PITT_091_NeuN_pl  2020-03-13T20:18:24.555Z  @taejeong   @cmolitor  169.931067
# MSSM_304_muscle   2020-03-13T20:18:20.620Z  @taejeong   @cmolitor  103.079064
# MSSM_369_muscle   2020-03-13T20:18:19.182Z  @taejeong   @cmolitor   64.679641
# MSSM_109_NeuN_pl  2020-03-13T20:26:47.587Z  @taejeong   @cmolitor  312.922528
# MSSM_391_NeuN_mn  2020-03-13T20:20:11.338Z  @taejeong   @cmolitor   43.768166
# MSSM_056_muscle   2020-03-13T20:18:16.206Z  @taejeong   @cmolitor   52.598372
# MSSM_369_NeuN_mn  2020-03-13T20:18:16.937Z  @taejeong   @cmolitor   54.586884
# PITT_064_NeuN_mn  2020-03-13T20:20:12.271Z  @taejeong   @cmolitor   49.015365
# PITT_064_NeuN_pl  2020-03-13T20:20:15.298Z  @taejeong   @cmolitor  259.668886
# MSSM_369_NeuN_pl  2020-03-13T20:20:05.633Z  @taejeong   @cmolitor  186.023140
# MSSM_106_NeuN_mn  2020-03-13T20:18:16.812Z  @taejeong   @cmolitor   55.699787
# PITT_010_NeuN_pl  2020-03-13T20:20:05.080Z  @taejeong   @cmolitor  163.661253
# PITT_010_NeuN_mn  2020-03-13T20:18:17.061Z  @taejeong   @cmolitor   43.396741
# MSSM_109_NeuN_mn  2020-03-13T20:20:12.393Z  @taejeong   @cmolitor   45.572326
# MSSM_215_NeuN_pl  2020-03-13T20:20:13.430Z  @taejeong   @cmolitor  229.498986
# MSSM_179_muscle   2020-03-13T20:18:17.188Z  @taejeong   @cmolitor   47.025076
# MSSM_179_NeuN_pl  2020-03-13T20:20:14.676Z  @taejeong   @cmolitor  206.253199
# MSSM_391_muscle   2020-03-13T20:18:17.506Z  @taejeong   @cmolitor   48.685088
# MSSM_183_NeuN_pl  2020-03-13T20:20:13.679Z  @taejeong   @cmolitor  213.282195
# MSSM_179_NeuN_mn  2020-03-13T20:18:16.556Z  @taejeong   @cmolitor   45.389837
# MSSM_106_muscle   2020-03-13T20:19:32.261Z  @taejeong   @cmolitor   61.918579
# MSSM_331_muscle   2020-03-13T20:18:19.327Z  @taejeong   @cmolitor   62.480753
# PITT_118_NeuN_pl  2020-03-13T20:20:14.269Z  @taejeong   @cmolitor  246.478912
# MSSM_391_NeuN_pl  2020-03-13T20:20:14.804Z  @taejeong   @cmolitor  164.988092
# MSSM_109_muscle   2020-03-13T20:18:16.325Z  @taejeong   @cmolitor   56.561396
# PITT_091_NeuN_mn  2020-03-13T20:18:18.399Z  @taejeong   @cmolitor   59.405017

# %% [markdown]
# ### Unprocessed samples from Ada
# Samples on Ada that have **not** been processed by bsmn-pipeline yet

# %%
samples_unprocessed = samples_ada - samples_scratch
samples_unprocessed_path = os.path.normpath(wdir + os.path.sep + 'unprocessed_samples')
with open(samples_unprocessed_path, 'w') as f:
    for s in samples_unprocessed:
        f.write(s + '\n')
print('written to', samples_unprocessed_path)
# Out:
# written to /home/attila/projects/bsm/results/2020-05-18-processed-samples/unprocessed_samples

# %%
# %%bash
# cat /home/attila/projects/bsm/results/2020-05-18-processed-samples/unprocessed_samples
# Out:
# MSSM_331_NeuN_pl
# PITT_060_NeuN_pl
# PITT_101_NeuN_pl
# MSSM_065_NeuN_pl
# MSSM_310_NeuN_pl
# MSSM_033_NeuN_pl
# MSSM_338_NeuN_pl
# MSSM_295_NeuN_pl
# MSSM_056_NeuN_pl
# PITT_036_NeuN_pl
# MSSM_304_NeuN_pl
# MSSM_193_NeuN_pl

# %% [markdown]
# These samples were uploaded to [s3://chesslab-bsmn/Ada/](https://s3.console.aws.amazon.com/s3/buckets/chesslab-bsmn/Ada/?region=us-east-2&tab=overview)

# %% [markdown]
# ### (Partially) processed samples from GENEWIZ 30-317737003
# Newest samples: GENEWIZ project 30-317737003

# %%
scratch.loc[samples_scratch - samples_ada, :]
# Out:
#                  Individual ID       Dx   Tissue              File name  \
# MSSM_366_NeuN_pl  CMC_MSSM_366      SCZ  NeuN_pl  MSSM_366_NeuN_pl.cram
# MSSM_224_NeuN_pl  CMC_MSSM_224      SCZ  NeuN_pl  MSSM_224_NeuN_pl.cram
# PITT_050_NeuN_pl  CMC_PITT_050  Control  NeuN_pl  PITT_050_NeuN_pl.cram
# MSSM_327_NeuN_pl  CMC_MSSM_327      SCZ  NeuN_pl  MSSM_327_NeuN_pl.cram
# PITT_072_NeuN_pl  CMC_PITT_072      SCZ  NeuN_pl  PITT_072_NeuN_pl.cram
# MSSM_321_NeuN_pl  CMC_MSSM_321      SCZ  NeuN_pl  MSSM_321_NeuN_pl.cram
# MSSM_346_NeuN_pl  CMC_MSSM_346      SCZ  NeuN_pl  MSSM_346_NeuN_pl.cram
# MSSM_192_NeuN_pl  CMC_MSSM_192      SCZ  NeuN_pl  MSSM_192_NeuN_pl.cram
# MSSM_269_NeuN_pl  CMC_MSSM_269      SCZ  NeuN_pl  MSSM_269_NeuN_pl.cram
# MSSM_213_NeuN_pl  CMC_MSSM_213      SCZ  NeuN_pl  MSSM_213_NeuN_pl.cram
# MSSM_027_NeuN_pl  CMC_MSSM_027      SCZ  NeuN_pl  MSSM_027_NeuN_pl.cram
# MSSM_415_NeuN_pl  CMC_MSSM_415      SCZ  NeuN_pl  MSSM_415_NeuN_pl.cram
# MSSM_370_NeuN_pl  CMC_MSSM_370      SCZ  NeuN_pl  MSSM_370_NeuN_pl.cram
# MSSM_352_NeuN_pl  CMC_MSSM_352      SCZ  NeuN_pl  MSSM_352_NeuN_pl.cram
# MSSM_348_NeuN_pl  CMC_MSSM_348      SCZ  NeuN_pl  MSSM_348_NeuN_pl.cram
# MSSM_168_NeuN_pl  CMC_MSSM_168      SCZ  NeuN_pl  MSSM_168_NeuN_pl.cram
# MSSM_222_NeuN_pl  CMC_MSSM_222      SCZ  NeuN_pl  MSSM_222_NeuN_pl.cram
# MSSM_142_NeuN_pl  CMC_MSSM_142      SCZ  NeuN_pl  MSSM_142_NeuN_pl.cram
# MSSM_364_NeuN_pl  CMC_MSSM_364      SCZ  NeuN_pl  MSSM_364_NeuN_pl.cram
# MSSM_372_NeuN_pl  CMC_MSSM_372      SCZ  NeuN_pl  MSSM_372_NeuN_pl.cram
# PITT_071_NeuN_pl  CMC_PITT_071      SCZ  NeuN_pl  PITT_071_NeuN_pl.cram
# PITT_117_NeuN_pl  CMC_PITT_117      SCZ  NeuN_pl  PITT_117_NeuN_pl.cram
#
#                          Modification time    Created by   Modified by  \
# MSSM_366_NeuN_pl  2020-05-01T11:10:17.453Z  @attilajones  @attilajones
# MSSM_224_NeuN_pl  2020-05-01T00:58:44.085Z  @attilajones  @attilajones
# PITT_050_NeuN_pl  2020-05-01T12:38:57.697Z  @attilajones  @attilajones
# MSSM_327_NeuN_pl  2020-05-01T12:47:36.932Z  @attilajones  @attilajones
# PITT_072_NeuN_pl  2020-05-01T07:18:57.829Z  @attilajones  @attilajones
# MSSM_321_NeuN_pl  2020-05-02T06:43:10.689Z  @attilajones  @attilajones
# MSSM_346_NeuN_pl  2020-05-01T08:40:51.936Z  @attilajones  @attilajones
# MSSM_192_NeuN_pl  2020-05-01T05:42:08.793Z  @attilajones  @attilajones
# MSSM_269_NeuN_pl  2020-05-02T01:03:59.082Z  @attilajones  @attilajones
# MSSM_213_NeuN_pl  2020-05-02T05:55:22.334Z  @attilajones  @attilajones
# MSSM_027_NeuN_pl  2020-05-02T15:56:53.425Z  @attilajones  @attilajones
# MSSM_415_NeuN_pl  2020-05-01T10:52:07.612Z  @attilajones  @attilajones
# MSSM_370_NeuN_pl  2020-05-02T03:12:50.548Z  @attilajones  @attilajones
# MSSM_352_NeuN_pl  2020-05-09T23:45:30.306Z  @attilajones  @attilajones
# MSSM_348_NeuN_pl  2020-04-29T17:04:24.280Z  @attilajones  @attilajones
# MSSM_168_NeuN_pl  2020-05-01T13:40:35.750Z  @attilajones  @attilajones
# MSSM_222_NeuN_pl  2020-05-01T14:39:36.442Z  @attilajones  @attilajones
# MSSM_142_NeuN_pl  2020-05-04T20:11:34.836Z  @attilajones  @attilajones
# MSSM_364_NeuN_pl  2020-05-02T08:23:40.485Z  @attilajones  @attilajones
# MSSM_372_NeuN_pl  2020-04-29T17:04:49.926Z  @attilajones  @attilajones
# PITT_071_NeuN_pl  2020-05-01T21:09:44.863Z  @attilajones  @attilajones
# PITT_117_NeuN_pl  2020-05-01T16:04:44.074Z  @attilajones  @attilajones
#
#                     Size GiB
# MSSM_366_NeuN_pl   44.041661
# MSSM_224_NeuN_pl   38.057367
# PITT_050_NeuN_pl   38.517650
# MSSM_327_NeuN_pl   50.819513
# PITT_072_NeuN_pl   32.506979
# MSSM_321_NeuN_pl   62.606365
# MSSM_346_NeuN_pl   40.556149
# MSSM_192_NeuN_pl   35.282288
# MSSM_269_NeuN_pl   50.057645
# MSSM_213_NeuN_pl   60.143387
# MSSM_027_NeuN_pl   59.431365
# MSSM_415_NeuN_pl   46.928385
# MSSM_370_NeuN_pl   59.757418
# MSSM_352_NeuN_pl  256.431132
# MSSM_348_NeuN_pl   48.998173
# MSSM_168_NeuN_pl   44.918223
# MSSM_222_NeuN_pl   40.088242
# MSSM_142_NeuN_pl  159.745002
# MSSM_364_NeuN_pl   51.587156
# MSSM_372_NeuN_pl   52.957125
# PITT_071_NeuN_pl   48.000333
# PITT_117_NeuN_pl   43.413392

# %% [markdown]
# ### Unprocessed samples from GENEWIZ 30-317737003

# %% [markdown]
# Take samples in g003 (`samples_g003`) as well as those on Ada or on the BSMN scratch space or both (`samples_ada_scratch`)

# %%
samples_g003 = set(g003.index)
samples_ada_scratch = samples_unprocessed.union(samples_scratch)
print(len(samples_g003), len(samples_ada_scratch))
# Out:
# 69 69

# %%
samples_missing_from_scratch = samples_g003 - samples_ada_scratch
len(samples_missing_from_scratch)
# Out:
# 47

# %% [markdown]
# ## List of all samples

# %%
sel_col = ['Individual ID', 'Dx', 'Tissue']
all_samples = pd.concat([ada.loc[samples_unprocessed, sel_col], \
                         scratch.loc[:, sel_col], \
                        g003.loc[samples_missing_from_scratch, sel_col]])
allsi = list(all_samples.index)
allsi.sort()
all_samples = all_samples.loc[allsi, :]
all_samples.to_csv(wdir + os.path.sep + 'all_samples.csv', index_label = 'Sample ID')
all_samples
# Out:
#                  Individual ID       Dx   Tissue
# MSSM_027_NeuN_pl  CMC_MSSM_027      SCZ  NeuN_pl
# MSSM_033_NeuN_pl  CMC_MSSM_033  Control  NeuN_pl
# MSSM_055_NeuN_pl  CMC_MSSM_055  Control  NeuN_pl
# MSSM_056_NeuN_pl  CMC_MSSM_056  Control  NeuN_pl
# MSSM_056_muscle   CMC_MSSM_056  Control   muscle
# ...                        ...      ...      ...
# PITT_101_NeuN_pl  CMC_PITT_101  Control  NeuN_pl
# PITT_113_NeuN_pl  CMC_PITT_113  Control  NeuN_pl
# PITT_117_NeuN_pl  CMC_PITT_117      SCZ  NeuN_pl
# PITT_118_NeuN_mn  CMC_PITT_118      SCZ  NeuN_mn
# PITT_118_NeuN_pl  CMC_PITT_118      SCZ  NeuN_pl
#
# [116 rows x 3 columns]

# %%
print(len(set(all_samples['Individual ID'])),'individuals')
# Out:
# 95 individuals

# %%
all_samples.groupby(['Dx', 'Tissue']).count()
# Out:
#                  Individual ID
# Dx      Tissue
# Control NeuN_mn              8
#         NeuN_pl             28
#         muscle               7
# SCZ     NeuN_mn              2
#         NeuN_pl             67
#         muscle               4

# %% [markdown]
# List Control individuals with samples from multiple tissues

# %%
samplecounts = all_samples.groupby(['Individual ID']).count()
multisample_indivs = samplecounts.loc[samplecounts['Tissue'] > 1, :].index
multisample_indivs
multisamples = all_samples.loc[all_samples['Individual ID'].isin(multisample_indivs), :]
def count_multisamples(Dx='Control'):
    res = multisamples.loc[multisamples['Dx'] == Dx, :].groupby(['Individual ID', 'Tissue']).count()
    return(res)
count_multisamples('Control')
# Out:
#                        Dx
# Individual ID Tissue
# CMC_MSSM_056  NeuN_pl   1
#               muscle    1
# CMC_MSSM_106  NeuN_mn   1
#               NeuN_pl   1
#               muscle    1
# CMC_MSSM_109  NeuN_mn   1
#               NeuN_pl   1
#               muscle    1
# CMC_MSSM_179  NeuN_mn   1
#               NeuN_pl   1
#               muscle    1
# CMC_MSSM_183  NeuN_mn   1
#               NeuN_pl   1
#               muscle    1
# CMC_MSSM_369  NeuN_mn   1
#               NeuN_pl   1
#               muscle    1
# CMC_MSSM_391  NeuN_mn   1
#               NeuN_pl   1
#               muscle    1
# CMC_PITT_010  NeuN_mn   1
#               NeuN_pl   1
# CMC_PITT_064  NeuN_mn   1
#               NeuN_pl   1

# %% [markdown]
# The same for SCZ individuals

# %%
count_multisamples('SCZ')
# Out:
#                        Dx
# Individual ID Tissue
# CMC_MSSM_118  NeuN_pl   1
#               muscle    1
# CMC_MSSM_295  NeuN_pl   1
#               muscle    1
# CMC_MSSM_304  NeuN_pl   1
#               muscle    1
# CMC_MSSM_331  NeuN_pl   1
#               muscle    1
# CMC_PITT_091  NeuN_mn   1
#               NeuN_pl   1
# CMC_PITT_118  NeuN_mn   1
#               NeuN_pl   1

# %%
# %connect_info
# Out:
# {
#   "shell_port": 52163,
#   "iopub_port": 33735,
#   "stdin_port": 33889,
#   "control_port": 52717,
#   "hb_port": 36263,
#   "ip": "127.0.0.1",
#   "key": "38a7fd56-bbafb792ab1ef25184f82a10",
#   "transport": "tcp",
#   "signature_scheme": "hmac-sha256",
#   "kernel_name": ""
# }
#
# Paste the above JSON into a file, and connect with:
#     $> jupyter <app> --existing <file>
# or, if you are local, you can connect with just:
#     $> jupyter <app> --existing kernel-10c2cc45-dd08-4173-a0a4-62c9838e9caf.json
# or even just:
#     $> jupyter <app> --existing
# if this is the most recent Jupyter kernel you have started.
