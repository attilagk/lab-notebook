# %% [markdown]
# Here we inspect variant allele frequency (VAF) distribution after Taejeong Bae et al 2018 (Science 359 (6375), 550-555).

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import attila_utils
import matplotlib
matplotlib.rcParams['figure.dpi'] = 150
#matplotlib.rcParams['figure.figsize'] = [7, 5]
from IPython.display import set_matplotlib_formats
#set_matplotlib_formats('png', 'pdf')

# %%
import truth_sets_aaf as tsa
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

# %% [markdown]
# Import the VAF values for all variants in sample S316 and S320

# %%
vaf_emp = tsa.get_taejeongs_aaf(samples=['S316', 'S320'], scale2pct=True)

# %%
g = tsa.aaf_distplot(vaf_emp, fit=None)
attila_utils.savefig(g, 'tj-vaf-hist')
g = tsa.aaf_distplot(vaf_emp, fit=None, onesample='pooled')
attila_utils.savefig(g, 'tj-vaf-hist-pooled')
# Out:
# ['named-figure/tj-vaf-hist-pooled.png', 'named-figure/tj-vaf-hist-pooled.pdf']

# %%
d = {c: tsa.lambda_hat(vaf_emp[vaf_emp['sample'] == c]['VAF']) for c in vaf_emp['sample'].cat.categories}
pd.DataFrame(d, index=['lambda_hat'])
# Out:
#                 S316      S320    pooled
# lambda_hat  0.221052  0.235704  0.224425

# %%
g = tsa.aaf_distplot(vaf_emp, fit=stats.expon, onesample=None)
attila_utils.savefig(g, 'tj-vaf-hist-expon')
g = tsa.aaf_distplot(vaf_emp, fit=stats.expon, onesample='pooled')
attila_utils.savefig(g, 'tj-vaf-hist-expon-pooled')
# Out:
# ['named-figure/tj-vaf-hist-expon-pooled.png',
#  'named-figure/tj-vaf-hist-expon-pooled.pdf']

# %%
# %connect_info
# Out:
# {
#   "shell_port": 50695,
#   "iopub_port": 46827,
#   "stdin_port": 60225,
#   "control_port": 58153,
#   "hb_port": 34149,
#   "ip": "127.0.0.1",
#   "key": "7fe3c911-a7b9153b08aa4dcd2ef62e1a",
#   "transport": "tcp",
#   "signature_scheme": "hmac-sha256",
#   "kernel_name": ""
# }
#
# Paste the above JSON into a file, and connect with:
#     $> jupyter <app> --existing <file>
# or, if you are local, you can connect with just:
#     $> jupyter <app> --existing kernel-4ffb474e-ccef-484f-a55a-ed82c7be78ba.json
# or even just:
#     $> jupyter <app> --existing
# if this is the most recent Jupyter kernel you have started.
