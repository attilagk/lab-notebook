# %% [markdown]
# Checking data on NeuN+ samples for CMC individual IDs MSSM_056 MSSM_193 MSSM_331 PITT_060 PITT_101 PITT_036 PITT_060 MSSM_304.  The FASTQ files reside in the 2016-10-11-HK and 2016-08-15-DV-X10 subdirectories under ada:/projects/bsm/reads/

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import attila_utils
import correct_rg_HK
import data_check
import pandas as pd

# %%
pwd
# Out:
# '/home/attila/projects/bsm/notebook/2019-11-19-data-check'

# %%
# %%bash
# cd /projects/bsm/attila/results/2019-11-19-data-check
# for sample in MSSM_056 MSSM_193 MSSM_331 PITT_060 MSSM_295 PITT_101 PITT_036 MSSM_304; do
#     find /projects/bsm/alignments/ -name "${sample}_NeuN_pl.bam"
# done > CMC-bam-names
# cat CMC-bam-names
# Out:
# /projects/bsm/alignments/MSSM_056/MSSM_056_NeuN_pl.bam
# /projects/bsm/alignments/MSSM_193/MSSM_193_NeuN_pl.bam
# /projects/bsm/alignments/MSSM_331/MSSM_331_NeuN_pl.bam
# /projects/bsm/alignments/PITT_060/PITT_060_NeuN_pl.bam
# /projects/bsm/alignments/MSSM_295/MSSM_295_NeuN_pl.bam
# /projects/bsm/alignments/PITT_101/PITT_101_NeuN_pl.bam
# /projects/bsm/alignments/PITT_036/PITT_036_NeuN_pl.bam
# /projects/bsm/alignments/MSSM_304/MSSM_304_NeuN_pl.bam

# %% [markdown]
# ## Mapped reads

# %%
indivs = ['MSSM_056', 'MSSM_193', 'MSSM_331', 'PITT_060', 'MSSM_295', 'PITT_101', 'PITT_036', 'MSSM_304']
idxstats = pd.concat([data_check.idxstats(s, 'NeuN_pl') for s in indivs], axis=0)
idxstats
# Out:
#           Name     Length     Mapped  Unmapped  % Unmapped            Sample
# 0            1  249250621  191689852    235579    0.122745  MSSM_056_NeuN_pl
# 1            2  243199373  203441520    262257    0.128744  MSSM_056_NeuN_pl
# 2            3  198022430  164530889    201522    0.122333  MSSM_056_NeuN_pl
# 3            4  191154276  158845796    194178    0.122094  MSSM_056_NeuN_pl
# 4            5  180915260  150585880    185074    0.122752  MSSM_056_NeuN_pl
# ..         ...        ...        ...       ...         ...               ...
# 82  GL000225.1     211173     408011       949    0.232052  MSSM_304_NeuN_pl
# 83  GL000192.1     547496     483138       880    0.181811  MSSM_304_NeuN_pl
# 84   NC_007605     171823       1455        53    3.514589  MSSM_304_NeuN_pl
# 85      hs37d5   35477943  158475898    263545    0.166024  MSSM_304_NeuN_pl
# 86           *          0          0  64668948  100.000000  MSSM_304_NeuN_pl
#
# [696 rows x 6 columns]

# %%
fig = data_check.idxstats_contig_plot(idxstats)
attila_utils.savefig(fig, 'unmapped-reads')
# Out:
# ['named-figure/unmapped-reads.png', 'named-figure/unmapped-reads.pdf']

# %% [markdown]
# The results show that for all samples most of the reads have been mapped suggesting good quality.

# %% [markdown]
# ## Sample purity and label swap
#
# Once again `verifyBamID` is used to examine sample purity and label swap by calculating FREEMIX and CHIPMIX, respectively.

# %%
# %%bash
# if false; then
#     cd /projects/bsm/attila/results/2019-11-19-data-check
#     script=/home/attila/projects/bsm/notebook/2018-12-18-verifyBamID/CMCverifyBamID.2
#     for bam in `cat CMC-bam-names`; do
#         $script $bam &
#     done
# fi

# %%
# %%bash
# cd /projects/bsm/attila/results/2019-11-19-data-check
# /home/attila/projects/bsm/notebook/2018-12-18-verifyBamID/aggregate-selfSM
# echo output file:
# realpath all.selfSM
# Out:
# output file:
# /projects/bsm/attila/results/2019-11-19-data-check/all.selfSM

# %%
selfSM = pd.read_csv('/projects/bsm/attila/results/2019-11-19-data-check/all.selfSM', sep='\t')
selfSM
# Out:
#              sample   indivID   tissue       SEQ_ID   RG      CHIP_ID    SNPS  \
# 0  MSSM_056_NeuN_pl  MSSM_056  NeuN_pl   0_MSSM_127  ALL   0_MSSM_127  668238
# 1  MSSM_193_NeuN_pl  MSSM_193  NeuN_pl   0_MSSM_250  ALL   0_MSSM_250  668238
# 2  MSSM_295_NeuN_pl  MSSM_295  NeuN_pl   0_MSSM_342  ALL   0_MSSM_342  668238
# 3  MSSM_304_NeuN_pl  MSSM_304  NeuN_pl   0_MSSM_350  ALL   0_MSSM_350  668238
# 4  MSSM_331_NeuN_pl  MSSM_331  NeuN_pl   0_MSSM_375  ALL   0_MSSM_375  668238
# 5  PITT_036_NeuN_pl  PITT_036  NeuN_pl  0_PITT_1307  ALL  0_PITT_1307  668238
# 6  PITT_060_NeuN_pl  PITT_060  NeuN_pl  0_PITT_1542  ALL  0_PITT_1542  668238
# 7  PITT_101_NeuN_pl  PITT_101  NeuN_pl   0_PITT_700  ALL   0_PITT_700  668238
#
#       READS  AVG_DP  FREEMIX  ...  FREE_RH  FREE_RA  CHIPMIX     CHIPLK1  \
# 0  13049448   19.53  0.00586  ...      NaN      NaN  0.00569  2943924.65
# 1  13049723   19.53  0.00357  ...      NaN      NaN  0.00343  2890090.14
# 2  13049901   19.53  0.00937  ...      NaN      NaN  0.00836  2943553.71
# 3  13050046   19.53  0.01537  ...      NaN      NaN  0.01379  2998331.46
# 4  13049659   19.53  0.00468  ...      NaN      NaN  0.00470  2983124.63
# 5  13049501   19.53  0.01085  ...      NaN      NaN  0.00987  3149066.17
# 6  13049499   19.53  0.00324  ...      NaN      NaN  0.00314  2862163.44
# 7  13049878   19.53  0.02018  ...      NaN      NaN  0.01766  3069901.72
#
#       CHIPLK0  CHIP_RH  CHIP_RA   DPREF  RDPHET  RDPALT
# 0  2974025.13      NaN      NaN  19.516  1.0017  1.0020
# 1  2905634.06      NaN      NaN  19.418  1.0294  0.9623
# 2  2993902.32      NaN      NaN  19.408  1.0299  0.9652
# 3  3094911.42      NaN      NaN  19.416  1.0295  0.9631
# 4  3011881.48      NaN      NaN  19.561  0.9962  0.9959
# 5  3220729.26      NaN      NaN  19.426  1.0288  0.9624
# 6  2875543.44      NaN      NaN  19.416  1.0294  0.9632
# 7  3198538.96      NaN      NaN  19.404  1.0301  0.9665
#
# [8 rows x 22 columns]

# %%
fig = data_check.selfSMplot(selfSM)
attila_utils.savefig(fig, 'freemix')
# Out:
# ['named-figure/freemix.png', 'named-figure/freemix.pdf']

# %% [markdown]
# The figure shows excellent purity and no evidence for label swap across all samples.
